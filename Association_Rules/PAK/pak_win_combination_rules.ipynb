# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
import math

# %%
match_data = pd.read_csv('pak_data.csv')

# %%
match_data.head()
# Out:
#   Day_Night Result  Home  Bat  Toss     Opposition              p1  \
# 0        DN   lost     0    1  lost  v New Zealand      Ehsan Adil
# 1        DN   lost     0    2  lost  v New Zealand      Ehsan Adil
# 2        DN   lost     0    2  lost        v India  Sohaib Maqsood
# 3         D   lost     0    2   won  v West Indies  Sohaib Maqsood
# 4        DN    won     0    1   won     v Zimbabwe  Sohaib Maqsood
#
#               p2               p3           p4             p5            p6  \
# 0  Ahmed Shehzad  Mohammad Hafeez  Younis Khan  Shahid Afridi  Haris Sohail
# 1  Ahmed Shehzad  Mohammad Hafeez  Younis Khan  Shahid Afridi  Haris Sohail
# 2  Ahmed Shehzad       Wahab Riaz  Younis Khan  Shahid Afridi  Haris Sohail
# 3  Ahmed Shehzad       Wahab Riaz  Younis Khan  Shahid Afridi  Haris Sohail
# 4  Ahmed Shehzad       Wahab Riaz    Rahat Ali  Shahid Afridi  Haris Sohail
#
#               p7          p8              p9             p10             p11
# 0  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan  Bilawal Bhatti  Sarfaraz Ahmed
# 1  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan  Bilawal Bhatti  Sarfaraz Ahmed
# 2  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan      Yasir Shah     Sohail Khan
# 3  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan   Nasir Jamshed     Sohail Khan
# 4  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan   Nasir Jamshed     Sohail Khan

# %%
del match_data["Day_Night"]
del match_data["Home"]
del match_data["Bat"]
del match_data["Toss"]
del match_data["Opposition"]

# %%
match_data
# Out:
#    Result              p1             p2               p3               p4  \
# 0    lost      Ehsan Adil  Ahmed Shehzad  Mohammad Hafeez      Younis Khan
# 1    lost      Ehsan Adil  Ahmed Shehzad  Mohammad Hafeez      Younis Khan
# 2    lost  Sohaib Maqsood  Ahmed Shehzad       Wahab Riaz      Younis Khan
# 3    lost  Sohaib Maqsood  Ahmed Shehzad       Wahab Riaz      Younis Khan
# 4     won  Sohaib Maqsood  Ahmed Shehzad       Wahab Riaz        Rahat Ali
# ..    ...             ...            ...              ...              ...
# 89    won     Imam-ul-Haq   Fakhar Zaman       Babar Azam  Mohammad Hafeez
# 90    won    Fakhar Zaman    Imam-ul-Haq       Babar Azam  Mohammad Hafeez
# 91    won    Fakhar Zaman    Imam-ul-Haq       Babar Azam  Mohammad Hafeez
# 92    won    Fakhar Zaman    Imam-ul-Haq       Babar Azam     Haris Sohail
# 93    won    Fakhar Zaman       Abid Ali       Babar Azam   Sarfaraz Ahmed
#
#                 p5              p6              p7              p8  \
# 0    Shahid Afridi    Haris Sohail   Misbah-ul-Haq      Umar Akmal
# 1    Shahid Afridi    Haris Sohail   Misbah-ul-Haq      Umar Akmal
# 2    Shahid Afridi    Haris Sohail   Misbah-ul-Haq      Umar Akmal
# 3    Shahid Afridi    Haris Sohail   Misbah-ul-Haq      Umar Akmal
# 4    Shahid Afridi    Haris Sohail   Misbah-ul-Haq      Umar Akmal
# ..             ...             ...             ...             ...
# 89    Haris Sohail  Sarfaraz Ahmed      Imad Wasim      Wahab Riaz
# 90    Haris Sohail  Sarfaraz Ahmed      Imad Wasim     Shadab Khan
# 91    Haris Sohail      Imad Wasim  Sarfaraz Ahmed      Wahab Riaz
# 92  Sarfaraz Ahmed  Iftikhar Ahmed      Imad Wasim      Wahab Riaz
# 93    Haris Sohail  Iftikhar Ahmed      Wahab Riaz  Mohammad Nawaz
#
#                 p9             p10                  p11
# 0   Mohammad Irfan  Bilawal Bhatti       Sarfaraz Ahmed
# 1   Mohammad Irfan  Bilawal Bhatti       Sarfaraz Ahmed
# 2   Mohammad Irfan      Yasir Shah          Sohail Khan
# 3   Mohammad Irfan   Nasir Jamshed          Sohail Khan
# 4   Mohammad Irfan   Nasir Jamshed          Sohail Khan
# ..             ...             ...                  ...
# 89     Shadab Khan   Mohammad Amir  Shaheen Shah Afridi
# 90      Wahab Riaz   Mohammad Amir  Shaheen Shah Afridi
# 91     Shadab Khan   Mohammad Amir  Shaheen Shah Afridi
# 92     Shadab Khan   Mohammad Amir       Usman Shinwari
# 93     Shadab Khan   Mohammad Amir       Usman Shinwari
#
# [94 rows x 12 columns]

# %%
# convert our pandas dataframe into a list of lists,
player_combo = [] #list of lists match players and result
for i in range(0, 94):
    rowItem = []
    for j in range(0, 12):
        rowItem.append(str(match_data.values[i,j]))
    player_combo.append(rowItem)

# %%
#Creating the dataframe of frequent itemsets
te = TransactionEncoder()
te_ary = te.fit(player_combo).transform(player_combo)
match_df_freq = pd.DataFrame(te_ary, columns=te.columns_)

# %%
match_sup = apriori(match_df_freq, min_support=0.1,use_colnames=True)
print(match_sup)
# Out:
#        support                                           itemsets
# 0     0.244681                                    (Ahmed Shehzad)
# 1     0.127660                                        (Anwar Ali)
# 2     0.159574                                         (Asif Ali)
# 3     0.414894                                        (Azhar Ali)
# 4     0.744681                                       (Babar Azam)
# ...        ...                                                ...
# 2329  0.127660  (Babar Azam, Shadab Khan, Shoaib Malik, Hasan ...
# 2330  0.106383  (Babar Azam, Shoaib Malik, Hasan Ali, won, Fak...
# 2331  0.106383  (Imam-ul-Haq, Babar Azam, Shadab Khan, Shoaib ...
# 2332  0.117021  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...
# 2333  0.117021  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...
#
# [2334 rows x 2 columns]

# %%
rules= association_rules(match_sup, metric="lift", min_threshold=1)

# %%
rules
# Out:
#              antecedents                                        consequents  \
# 0            (Azhar Ali)                                    (Ahmed Shehzad)
# 1        (Ahmed Shehzad)                                        (Azhar Ali)
# 2      (Mohammad Hafeez)                                    (Ahmed Shehzad)
# 3        (Ahmed Shehzad)                                  (Mohammad Hafeez)
# 4       (Mohammad Irfan)                                    (Ahmed Shehzad)
# ...                  ...                                                ...
# 51483        (Hasan Ali)  (Babar Azam, Shoaib Malik, Shadab Khan, won, I...
# 51484              (won)  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...
# 51485       (Imad Wasim)  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...
# 51486   (Sarfaraz Ahmed)  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...
# 51487  (Mohammad Hafeez)  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...
#
#        antecedent support  consequent support   support  confidence      lift  \
# 0                0.414894            0.244681  0.106383    0.256410  1.047938
# 1                0.244681            0.414894  0.106383    0.434783  1.047938
# 2                0.670213            0.244681  0.180851    0.269841  1.102830
# 3                0.244681            0.670213  0.180851    0.739130  1.102830
# 4                0.234043            0.244681  0.159574    0.681818  2.786561
# ...                   ...                 ...       ...         ...       ...
# 51483            0.531915            0.117021  0.117021    0.220000  1.880000
# 51484            0.468085            0.170213  0.117021    0.250000  1.468750
# 51485            0.553191            0.138298  0.117021    0.211538  1.529586
# 51486            0.829787            0.117021  0.117021    0.141026  1.205128
# 51487            0.670213            0.117021  0.117021    0.174603  1.492063
#
#        leverage  conviction
# 0      0.004866    1.015774
# 1      0.004866    1.035188
# 2      0.016863    1.034459
# 3      0.016863    1.264184
# 4      0.102309    2.373860
# ...         ...         ...
# 51483  0.054776    1.132024
# 51484  0.037347    1.106383
# 51485  0.040516    1.092891
# 51486  0.019919    1.027945
# 51487  0.038592    1.069763
#
# [51488 rows x 9 columns]

# %%
won_rules = rules[(rules['consequents'] == {"won"})]

# %%
won_rules
# Out:
#                                              antecedents consequents  \
# 13                                       (Ahmed Shehzad)       (won)
# 89                                          (Babar Azam)       (won)
# 127                                       (Fakhar Zaman)       (won)
# 159                                          (Hasan Ali)       (won)
# 178                                         (Imad Wasim)       (won)
# ...                                                  ...         ...
# 49971  (Shoaib Malik, Shadab Khan, Hasan Ali, Fakhar ...       (won)
# 50097  (Shoaib Malik, Shadab Khan, Hasan Ali, Imad Wa...       (won)
# 50478  (Babar Azam, Shoaib Malik, Hasan Ali, Fakhar Z...       (won)
# 50983  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...       (won)
# 51237  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...       (won)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 13               0.244681            0.468085  0.117021    0.478261  1.021739
# 89               0.744681            0.468085  0.372340    0.500000  1.068182
# 127              0.457447            0.468085  0.265957    0.581395  1.242072
# 159              0.531915            0.468085  0.255319    0.480000  1.025455
# 178              0.553191            0.468085  0.297872    0.538462  1.150350
# ...                   ...                 ...       ...         ...       ...
# 49971            0.191489            0.468085  0.117021    0.611111  1.305556
# 50097            0.170213            0.468085  0.117021    0.687500  1.468750
# 50478            0.159574            0.468085  0.106383    0.666667  1.424242
# 50983            0.191489            0.468085  0.117021    0.611111  1.305556
# 51237            0.170213            0.468085  0.117021    0.687500  1.468750
#
#        leverage  conviction
# 13     0.002490    1.019504
# 89     0.023766    1.063830
# 127    0.051833    1.270686
# 159    0.006338    1.022913
# 178    0.038932    1.152482
# ...         ...         ...
# 49971  0.027388    1.367781
# 50097  0.037347    1.702128
# 50478  0.031689    1.595745
# 50983  0.027388    1.367781
# 51237  0.037347    1.702128
#
# [449 rows x 9 columns]

# %%
won_rules = won_rules[(won_rules['antecedents'].str.len() > 1)] #Here won_rules['antecedents'] is a frozenset

# %%
won_rules
# Out:
#                                              antecedents consequents  \
# 357                      (Sarfaraz Ahmed, Ahmed Shehzad)       (won)
# 628                              (Imad Wasim, Azhar Ali)       (won)
# 767                          (Azhar Ali, Sarfaraz Ahmed)       (won)
# 793                            (Azhar Ali, Shoaib Malik)       (won)
# 928                           (Fakhar Zaman, Babar Azam)       (won)
# ...                                                  ...         ...
# 49971  (Shoaib Malik, Shadab Khan, Hasan Ali, Fakhar ...       (won)
# 50097  (Shoaib Malik, Shadab Khan, Hasan Ali, Imad Wa...       (won)
# 50478  (Babar Azam, Shoaib Malik, Hasan Ali, Fakhar Z...       (won)
# 50983  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...       (won)
# 51237  (Babar Azam, Shoaib Malik, Shadab Khan, Hasan ...       (won)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 357              0.212766            0.468085  0.106383    0.500000  1.068182
# 628              0.223404            0.468085  0.138298    0.619048  1.322511
# 767              0.372340            0.468085  0.180851    0.485714  1.037662
# 793              0.351064            0.468085  0.180851    0.515152  1.100551
# 928              0.457447            0.468085  0.265957    0.581395  1.242072
# ...                   ...                 ...       ...         ...       ...
# 49971            0.191489            0.468085  0.117021    0.611111  1.305556
# 50097            0.170213            0.468085  0.117021    0.687500  1.468750
# 50478            0.159574            0.468085  0.106383    0.666667  1.424242
# 50983            0.191489            0.468085  0.117021    0.611111  1.305556
# 51237            0.170213            0.468085  0.117021    0.687500  1.468750
#
#        leverage  conviction
# 357    0.006790    1.063830
# 628    0.033726    1.396277
# 767    0.006564    1.034279
# 793    0.016523    1.097074
# 928    0.051833    1.270686
# ...         ...         ...
# 49971  0.027388    1.367781
# 50097  0.037347    1.702128
# 50478  0.031689    1.595745
# 50983  0.027388    1.367781
# 51237  0.037347    1.702128
#
# [438 rows x 9 columns]

# %%
won_rules.to_csv('pak_won_rules.csv')
