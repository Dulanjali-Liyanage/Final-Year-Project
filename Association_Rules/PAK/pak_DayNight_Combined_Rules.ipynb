# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
import math

# %%
match_data = pd.read_csv('pak_data.csv')

# %%
match_data.head()
# Out:
#   Day_Night Result  Home  Bat  Toss     Opposition              p1  \
# 0        DN   lost     0    1  lost  v New Zealand      Ehsan Adil
# 1        DN   lost     0    2  lost  v New Zealand      Ehsan Adil
# 2        DN   lost     0    2  lost        v India  Sohaib Maqsood
# 3         D   lost     0    2   won  v West Indies  Sohaib Maqsood
# 4        DN    won     0    1   won     v Zimbabwe  Sohaib Maqsood
#
#               p2               p3           p4             p5            p6  \
# 0  Ahmed Shehzad  Mohammad Hafeez  Younis Khan  Shahid Afridi  Haris Sohail
# 1  Ahmed Shehzad  Mohammad Hafeez  Younis Khan  Shahid Afridi  Haris Sohail
# 2  Ahmed Shehzad       Wahab Riaz  Younis Khan  Shahid Afridi  Haris Sohail
# 3  Ahmed Shehzad       Wahab Riaz  Younis Khan  Shahid Afridi  Haris Sohail
# 4  Ahmed Shehzad       Wahab Riaz    Rahat Ali  Shahid Afridi  Haris Sohail
#
#               p7          p8              p9             p10             p11
# 0  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan  Bilawal Bhatti  Sarfaraz Ahmed
# 1  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan  Bilawal Bhatti  Sarfaraz Ahmed
# 2  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan      Yasir Shah     Sohail Khan
# 3  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan   Nasir Jamshed     Sohail Khan
# 4  Misbah-ul-Haq  Umar Akmal  Mohammad Irfan   Nasir Jamshed     Sohail Khan

# %%
del match_data["Home"]
del match_data["Bat"]
del match_data["Toss"]
del match_data["Opposition"]

# %%
match_data
# Out:
#    Day_Night Result              p1             p2               p3  \
# 0         DN   lost      Ehsan Adil  Ahmed Shehzad  Mohammad Hafeez
# 1         DN   lost      Ehsan Adil  Ahmed Shehzad  Mohammad Hafeez
# 2         DN   lost  Sohaib Maqsood  Ahmed Shehzad       Wahab Riaz
# 3          D   lost  Sohaib Maqsood  Ahmed Shehzad       Wahab Riaz
# 4         DN    won  Sohaib Maqsood  Ahmed Shehzad       Wahab Riaz
# ..       ...    ...             ...            ...              ...
# 89         D    won     Imam-ul-Haq   Fakhar Zaman       Babar Azam
# 90         D    won    Fakhar Zaman    Imam-ul-Haq       Babar Azam
# 91         D    won    Fakhar Zaman    Imam-ul-Haq       Babar Azam
# 92        DN    won    Fakhar Zaman    Imam-ul-Haq       Babar Azam
# 93        DN    won    Fakhar Zaman       Abid Ali       Babar Azam
#
#                  p4              p5              p6              p7  \
# 0       Younis Khan   Shahid Afridi    Haris Sohail   Misbah-ul-Haq
# 1       Younis Khan   Shahid Afridi    Haris Sohail   Misbah-ul-Haq
# 2       Younis Khan   Shahid Afridi    Haris Sohail   Misbah-ul-Haq
# 3       Younis Khan   Shahid Afridi    Haris Sohail   Misbah-ul-Haq
# 4         Rahat Ali   Shahid Afridi    Haris Sohail   Misbah-ul-Haq
# ..              ...             ...             ...             ...
# 89  Mohammad Hafeez    Haris Sohail  Sarfaraz Ahmed      Imad Wasim
# 90  Mohammad Hafeez    Haris Sohail  Sarfaraz Ahmed      Imad Wasim
# 91  Mohammad Hafeez    Haris Sohail      Imad Wasim  Sarfaraz Ahmed
# 92     Haris Sohail  Sarfaraz Ahmed  Iftikhar Ahmed      Imad Wasim
# 93   Sarfaraz Ahmed    Haris Sohail  Iftikhar Ahmed      Wahab Riaz
#
#                 p8              p9             p10                  p11
# 0       Umar Akmal  Mohammad Irfan  Bilawal Bhatti       Sarfaraz Ahmed
# 1       Umar Akmal  Mohammad Irfan  Bilawal Bhatti       Sarfaraz Ahmed
# 2       Umar Akmal  Mohammad Irfan      Yasir Shah          Sohail Khan
# 3       Umar Akmal  Mohammad Irfan   Nasir Jamshed          Sohail Khan
# 4       Umar Akmal  Mohammad Irfan   Nasir Jamshed          Sohail Khan
# ..             ...             ...             ...                  ...
# 89      Wahab Riaz     Shadab Khan   Mohammad Amir  Shaheen Shah Afridi
# 90     Shadab Khan      Wahab Riaz   Mohammad Amir  Shaheen Shah Afridi
# 91      Wahab Riaz     Shadab Khan   Mohammad Amir  Shaheen Shah Afridi
# 92      Wahab Riaz     Shadab Khan   Mohammad Amir       Usman Shinwari
# 93  Mohammad Nawaz     Shadab Khan   Mohammad Amir       Usman Shinwari
#
# [94 rows x 13 columns]

# %%
match_data['Day_Night'].unique()
# Out:
# array(['DN', 'D'], dtype=object)

# %%
player_combo = [] #list of lists match players and result
for i in range(0, 94):
    rowItem = []
    for j in range(0, 13):
        rowItem.append(str(match_data.values[i,j]))
    player_combo.append(rowItem)

# %%
te = TransactionEncoder()
te_ary = te.fit(player_combo).transform(player_combo)
match_df_freq = pd.DataFrame(te_ary, columns=te.columns_)

# %%
match_sup = apriori(match_df_freq, min_support=0.1,use_colnames=True)
match_sup
# Out:
#        support                                           itemsets
# 0     0.244681                                    (Ahmed Shehzad)
# 1     0.127660                                        (Anwar Ali)
# 2     0.159574                                         (Asif Ali)
# 3     0.414894                                        (Azhar Ali)
# 4     0.744681                                       (Babar Azam)
# ...        ...                                                ...
# 3378  0.127660  (Imad Wasim, Shadab Khan, Babar Azam, Sarfaraz...
# 3379  0.106383  (Imad Wasim, Babar Azam, Sarfaraz Ahmed, Hasan...
# 3380  0.106383  (Shadab Khan, Babar Azam, Sarfaraz Ahmed, Hasa...
# 3381  0.117021  (Shadab Khan, Babar Azam, Sarfaraz Ahmed, Hasa...
# 3382  0.117021  (Imad Wasim, Shadab Khan, Babar Azam, Sarfaraz...
#
# [3383 rows x 2 columns]

# %%
rules= association_rules(match_sup, metric="lift", min_threshold=1)

# %%
rules
# Out:
#              antecedents                                        consequents  \
# 0        (Ahmed Shehzad)                                        (Azhar Ali)
# 1            (Azhar Ali)                                    (Ahmed Shehzad)
# 2                   (DN)                                    (Ahmed Shehzad)
# 3        (Ahmed Shehzad)                                               (DN)
# 4      (Mohammad Hafeez)                                    (Ahmed Shehzad)
# ...                  ...                                                ...
# 78763   (Sarfaraz Ahmed)  (Imad Wasim, Shadab Khan, Babar Azam, Hasan Al...
# 78764        (Hasan Ali)  (Imad Wasim, Shadab Khan, Babar Azam, Sarfaraz...
# 78765              (won)  (Imad Wasim, Shadab Khan, Babar Azam, Sarfaraz...
# 78766  (Mohammad Hafeez)  (Imad Wasim, Shadab Khan, Babar Azam, Sarfaraz...
# 78767     (Shoaib Malik)  (Imad Wasim, Shadab Khan, Babar Azam, Sarfaraz...
#
#        antecedent support  consequent support   support  confidence      lift  \
# 0                0.244681            0.414894  0.106383    0.434783  1.047938
# 1                0.414894            0.244681  0.106383    0.256410  1.047938
# 2                0.595745            0.244681  0.148936    0.250000  1.021739
# 3                0.244681            0.595745  0.148936    0.608696  1.021739
# 4                0.670213            0.244681  0.180851    0.269841  1.102830
# ...                   ...                 ...       ...         ...       ...
# 78763            0.829787            0.117021  0.117021    0.141026  1.205128
# 78764            0.531915            0.117021  0.117021    0.220000  1.880000
# 78765            0.468085            0.170213  0.117021    0.250000  1.468750
# 78766            0.670213            0.117021  0.117021    0.174603  1.492063
# 78767            0.723404            0.117021  0.117021    0.161765  1.382353
#
#        leverage  conviction
# 0      0.004866    1.035188
# 1      0.004866    1.015774
# 2      0.003169    1.007092
# 3      0.003169    1.033097
# 4      0.016863    1.034459
# ...         ...         ...
# 78763  0.019919    1.027945
# 78764  0.054776    1.132024
# 78765  0.037347    1.106383
# 78766  0.038592    1.069763
# 78767  0.032368    1.053378
#
# [78768 rows x 9 columns]

# %%
won_rules = rules[(rules['consequents'] == {"won"})]

# %%
won_rules
# Out:
#                                              antecedents consequents  \
# 14                                       (Ahmed Shehzad)       (won)
# 98                                          (Babar Azam)       (won)
# 123                                                  (D)       (won)
# 183                                       (Fakhar Zaman)       (won)
# 214                                          (Hasan Ali)       (won)
# ...                                                  ...         ...
# 76235  (Shadab Khan, Sarfaraz Ahmed, Hasan Ali, Fakha...       (won)
# 76360  (Imad Wasim, Shadab Khan, Sarfaraz Ahmed, Hasa...       (won)
# 77757  (Imad Wasim, Babar Azam, Sarfaraz Ahmed, Hasan...       (won)
# 78263  (Shadab Khan, Babar Azam, Sarfaraz Ahmed, Hasa...       (won)
# 78516  (Imad Wasim, Shadab Khan, Babar Azam, Sarfaraz...       (won)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 14               0.244681            0.468085  0.117021    0.478261  1.021739
# 98               0.744681            0.468085  0.372340    0.500000  1.068182
# 123              0.404255            0.468085  0.223404    0.552632  1.180622
# 183              0.457447            0.468085  0.265957    0.581395  1.242072
# 214              0.531915            0.468085  0.255319    0.480000  1.025455
# ...                   ...                 ...       ...         ...       ...
# 76235            0.191489            0.468085  0.117021    0.611111  1.305556
# 76360            0.170213            0.468085  0.117021    0.687500  1.468750
# 77757            0.159574            0.468085  0.106383    0.666667  1.424242
# 78263            0.191489            0.468085  0.117021    0.611111  1.305556
# 78516            0.170213            0.468085  0.117021    0.687500  1.468750
#
#        leverage  conviction
# 14     0.002490    1.019504
# 98     0.023766    1.063830
# 123    0.034178    1.188986
# 183    0.051833    1.270686
# 214    0.006338    1.022913
# ...         ...         ...
# 76235  0.027388    1.367781
# 76360  0.037347    1.702128
# 77757  0.031689    1.595745
# 78263  0.027388    1.367781
# 78516  0.037347    1.702128
#
# [583 rows x 9 columns]

# %%
won_rules.values[0,:]
# Out:
# array([frozenset({'Ahmed Shehzad'}), frozenset({'won'}),
#        0.24468085106382978, 0.46808510638297873, 0.11702127659574468,
#        0.4782608695652174, 1.0217391304347827, 0.0024898143956541413,
#        1.0195035460992907], dtype=object)

# %%
col_names = ["antecedents","consequents","antecedent support","consequent support","support","confidence","lift","leverage","conviction"]
DN_won_rules = pd.DataFrame(columns = col_names)

# %%
i = 0
for x in won_rules['antecedents']:
    for y in x:
        if y == 'DN':
            #print(won_rules.values[i,0])
            DN_won_rules = DN_won_rules.append({'antecedents':won_rules.values[i,0],"consequents":won_rules.values[i,1],"antecedent support":won_rules.values[i,2],"consequent support":won_rules.values[i,3],"support":won_rules.values[i,4],"confidence":won_rules.values[i,5],"lift":won_rules.values[i,6],"leverage":won_rules.values[i,7],"conviction":won_rules.values[i,8]},ignore_index=True)
    i = i + 1

# %%
DN_won_rules
# Out:
#                                           antecedents consequents  \
# 0                                  (DN, Fakhar Zaman)       (won)
# 1                                     (Hasan Ali, DN)       (won)
# 2                                (Sarfaraz Ahmed, DN)       (won)
# 3                                   (DN, Shadab Khan)       (won)
# 4                      (DN, Babar Azam, Fakhar Zaman)       (won)
# 5                         (Hasan Ali, Babar Azam, DN)       (won)
# 6                        (Imad Wasim, DN, Babar Azam)       (won)
# 7                    (Sarfaraz Ahmed, DN, Babar Azam)       (won)
# 8                       (Shadab Khan, DN, Babar Azam)       (won)
# 9                  (Sarfaraz Ahmed, DN, Fakhar Zaman)       (won)
# 10                    (DN, Shadab Khan, Fakhar Zaman)       (won)
# 11                        (Imad Wasim, Hasan Ali, DN)       (won)
# 12                    (Sarfaraz Ahmed, Hasan Ali, DN)       (won)
# 13                      (Hasan Ali, Shoaib Malik, DN)       (won)
# 14                  (Imad Wasim, DN, Mohammad Hafeez)       (won)
# 15                   (Imad Wasim, Sarfaraz Ahmed, DN)       (won)
# 16                     (Imad Wasim, DN, Shoaib Malik)       (won)
# 17                (DN, Shoaib Malik, Mohammad Hafeez)       (won)
# 18                  (Sarfaraz Ahmed, DN, Shadab Khan)       (won)
# 19                 (Sarfaraz Ahmed, DN, Shoaib Malik)       (won)
# 20     (Sarfaraz Ahmed, DN, Babar Azam, Fakhar Zaman)       (won)
# 21        (DN, Shadab Khan, Babar Azam, Fakhar Zaman)       (won)
# 22            (Imad Wasim, Hasan Ali, DN, Babar Azam)       (won)
# 23        (Hasan Ali, Sarfaraz Ahmed, DN, Babar Azam)       (won)
# 24          (Hasan Ali, DN, Babar Azam, Shoaib Malik)       (won)
# 25       (Imad Wasim, Sarfaraz Ahmed, DN, Babar Azam)       (won)
# 26         (Imad Wasim, DN, Babar Azam, Shoaib Malik)       (won)
# 27      (Sarfaraz Ahmed, DN, Shadab Khan, Babar Azam)       (won)
# 28     (Sarfaraz Ahmed, DN, Babar Azam, Shoaib Malik)       (won)
# 29    (Sarfaraz Ahmed, DN, Shadab Khan, Fakhar Zaman)       (won)
# 30        (Imad Wasim, Sarfaraz Ahmed, DN, Hasan Ali)       (won)
# 31          (Imad Wasim, DN, Hasan Ali, Shoaib Malik)       (won)
# 32      (Sarfaraz Ahmed, DN, Hasan Ali, Shoaib Malik)       (won)
# 33    (Imad Wasim, DN, Shoaib Malik, Mohammad Hafeez)       (won)
# 34     (Imad Wasim, Sarfaraz Ahmed, DN, Shoaib Malik)       (won)
# 35  (Sarfaraz Ahmed, DN, Shoaib Malik, Mohammad Ha...       (won)
# 36  (Shadab Khan, Babar Azam, Sarfaraz Ahmed, DN, ...       (won)
# 37  (Imad Wasim, Babar Azam, Sarfaraz Ahmed, DN, H...       (won)
# 38  (Imad Wasim, Babar Azam, DN, Hasan Ali, Shoaib...       (won)
# 39  (Babar Azam, Sarfaraz Ahmed, DN, Hasan Ali, Sh...       (won)
# 40  (Imad Wasim, Babar Azam, Sarfaraz Ahmed, DN, S...       (won)
# 41  (Imad Wasim, Sarfaraz Ahmed, DN, Hasan Ali, Sh...       (won)
# 42  (Imad Wasim, Babar Azam, Sarfaraz Ahmed, DN, H...       (won)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.212766            0.468085  0.117021    0.550000  1.175000
# 1             0.287234            0.468085  0.138298    0.481481  1.028620
# 2             0.446809            0.468085  0.223404    0.500000  1.068182
# 3             0.180851            0.468085  0.106383    0.588235  1.256684
# 4             0.212766            0.468085  0.117021    0.550000  1.175000
# 5             0.287234            0.468085  0.138298    0.481481  1.028620
# 6             0.234043            0.468085  0.127660    0.545455  1.165289
# 7             0.319149            0.468085  0.159574    0.500000  1.068182
# 8             0.180851            0.468085  0.106383    0.588235  1.256684
# 9             0.202128            0.468085  0.117021    0.578947  1.236842
# 10            0.180851            0.468085  0.106383    0.588235  1.256684
# 11            0.202128            0.468085  0.117021    0.578947  1.236842
# 12            0.234043            0.468085  0.127660    0.545455  1.165289
# 13            0.255319            0.468085  0.138298    0.541667  1.157197
# 14            0.202128            0.468085  0.106383    0.526316  1.124402
# 15            0.212766            0.468085  0.138298    0.650000  1.388636
# 16            0.255319            0.468085  0.138298    0.541667  1.157197
# 17            0.308511            0.468085  0.148936    0.482759  1.031348
# 18            0.170213            0.468085  0.106383    0.625000  1.335227
# 19            0.329787            0.468085  0.180851    0.548387  1.171554
# 20            0.202128            0.468085  0.117021    0.578947  1.236842
# 21            0.180851            0.468085  0.106383    0.588235  1.256684
# 22            0.202128            0.468085  0.117021    0.578947  1.236842
# 23            0.234043            0.468085  0.127660    0.545455  1.165289
# 24            0.255319            0.468085  0.138298    0.541667  1.157197
# 25            0.180851            0.468085  0.117021    0.647059  1.382353
# 26            0.191489            0.468085  0.117021    0.611111  1.305556
# 27            0.170213            0.468085  0.106383    0.625000  1.335227
# 28            0.276596            0.468085  0.138298    0.500000  1.068182
# 29            0.170213            0.468085  0.106383    0.625000  1.335227
# 30            0.159574            0.468085  0.106383    0.666667  1.424242
# 31            0.170213            0.468085  0.117021    0.687500  1.468750
# 32            0.212766            0.468085  0.127660    0.600000  1.281818
# 33            0.191489            0.468085  0.106383    0.555556  1.186869
# 34            0.180851            0.468085  0.127660    0.705882  1.508021
# 35            0.255319            0.468085  0.138298    0.541667  1.157197
# 36            0.170213            0.468085  0.106383    0.625000  1.335227
# 37            0.159574            0.468085  0.106383    0.666667  1.424242
# 38            0.170213            0.468085  0.117021    0.687500  1.468750
# 39            0.212766            0.468085  0.127660    0.600000  1.281818
# 40            0.148936            0.468085  0.106383    0.714286  1.525974
# 41            0.138298            0.468085  0.106383    0.769231  1.643357
# 42            0.138298            0.468085  0.106383    0.769231  1.643357
#
#     leverage  conviction
# 0   0.017429    1.182033
# 1   0.003848    1.025836
# 2   0.014260    1.063830
# 3   0.021729    1.291793
# 4   0.017429    1.182033
# 5   0.003848    1.025836
# 6   0.018108    1.170213
# 7   0.010186    1.063830
# 8   0.021729    1.291793
# 9   0.022408    1.263298
# 10  0.021729    1.291793
# 11  0.022408    1.263298
# 12  0.018108    1.170213
# 13  0.018787    1.160542
# 14  0.011770    1.122931
# 15  0.038705    1.519757
# 16  0.018787    1.160542
# 17  0.004527    1.028369
# 18  0.026709    1.418440
# 19  0.026483    1.177812
# 20  0.022408    1.263298
# 21  0.021729    1.291793
# 22  0.022408    1.263298
# 23  0.018108    1.170213
# 24  0.018787    1.160542
# 25  0.032368    1.507092
# 26  0.027388    1.367781
# 27  0.026709    1.418440
# 28  0.008828    1.063830
# 29  0.026709    1.418440
# 30  0.031689    1.595745
# 31  0.037347    1.702128
# 32  0.028067    1.329787
# 33  0.016750    1.196809
# 34  0.043006    1.808511
# 35  0.018787    1.160542
# 36  0.026709    1.418440
# 37  0.031689    1.595745
# 38  0.037347    1.702128
# 39  0.028067    1.329787
# 40  0.036668    1.861702
# 41  0.041648    2.304965
# 42  0.041648    2.304965

# %%
DN_won_rules.to_csv('DN_won_rules.csv')

# %%
col_names = ["antecedents","consequents","antecedent support","consequent support","support","confidence","lift","leverage","conviction"]
D_won_rules = pd.DataFrame(columns = col_names)

# %%
i = 0
for x in won_rules['antecedents']:
    for y in x:
        if y == 'D':
            #print(won_rules.values[i,0])
            D_won_rules = D_won_rules.append({'antecedents':won_rules.values[i,0],"consequents":won_rules.values[i,1],"antecedent support":won_rules.values[i,2],"consequent support":won_rules.values[i,3],"support":won_rules.values[i,4],"confidence":won_rules.values[i,5],"lift":won_rules.values[i,6],"leverage":won_rules.values[i,7],"conviction":won_rules.values[i,8]},ignore_index=True)
    i = i + 1

# %%
D_won_rules#no rules
# Out:
#                                           antecedents consequents  \
# 0                                                 (D)       (won)
# 1                                     (Babar Azam, D)       (won)
# 2                                   (D, Fakhar Zaman)       (won)
# 3                                      (Hasan Ali, D)       (won)
# 4                                     (Imad Wasim, D)       (won)
# ..                                                ...         ...
# 86  (Mohammad Amir, Babar Azam, Sarfaraz Ahmed, D,...       (won)
# 87  (Mohammad Amir, Shadab Khan, Babar Azam, Sarfa...       (won)
# 88  (Shadab Khan, Babar Azam, Sarfaraz Ahmed, D, S...       (won)
# 89  (Shadab Khan, Sarfaraz Ahmed, D, Imam-ul-Haq, ...       (won)
# 90  (Shadab Khan, Babar Azam, Sarfaraz Ahmed, D, I...       (won)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.404255            0.468085  0.223404    0.552632  1.180622
# 1             0.361702            0.468085  0.202128    0.558824  1.193850
# 2             0.244681            0.468085  0.148936    0.608696  1.300395
# 3             0.244681            0.468085  0.117021    0.478261  1.021739
# 4             0.234043            0.468085  0.148936    0.636364  1.359504
# ..                 ...                 ...       ...         ...       ...
# 86            0.212766            0.468085  0.106383    0.500000  1.068182
# 87            0.191489            0.468085  0.117021    0.611111  1.305556
# 88            0.180851            0.468085  0.106383    0.588235  1.256684
# 89            0.138298            0.468085  0.106383    0.769231  1.643357
# 90            0.138298            0.468085  0.106383    0.769231  1.643357
#
#     leverage  conviction
# 0   0.034178    1.188986
# 1   0.032820    1.205674
# 2   0.034405    1.359338
# 3   0.002490    1.019504
# 4   0.039384    1.462766
# ..       ...         ...
# 86  0.006790    1.063830
# 87  0.027388    1.367781
# 88  0.021729    1.291793
# 89  0.041648    2.304965
# 90  0.041648    2.304965
#
# [91 rows x 9 columns]

# %%
D_won_rules.to_csv('D_won_rules.csv')
