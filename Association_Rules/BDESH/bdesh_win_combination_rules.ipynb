# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
import math

# %%
match_data = pd.read_csv('bdesh.csv')

# %%
match_data.head()
# Out:
#   Day_Night Result  Home  Bat  Toss     Opposition            p1  \
# 0        DN    won     0    1   won  v Afghanistan  Anamul Haque
# 1        DN   lost     0    2  lost    v Sri Lanka   Tamim Iqbal
# 2        DN    won     0    1  lost      v England   Tamim Iqbal
# 3        DN   lost     0    1  lost  v New Zealand   Tamim Iqbal
# 4        DN   lost     0    2  lost        v India   Tamim Iqbal
#
#              p2             p3             p4               p5  \
# 0   Tamim Iqbal  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
# 1  Anamul Haque  Soumya Sarkar  Mominul Haque      Mahmudullah
# 2   Imrul Kayes  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
# 3   Imrul Kayes  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
# 4   Imrul Kayes  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
#
#                 p6               p7                p8                p9  \
# 0  Mushfiqur Rahim    Sabbir Rahman  Mashrafe Mortaza   Mushfiqur Rahim
# 1  Shakib Al Hasan  Mushfiqur Rahim     Sabbir Rahman  Mashrafe Mortaza
# 2  Mushfiqur Rahim    Sabbir Rahman  Mashrafe Mortaza      Arafat Sunny
# 3  Mushfiqur Rahim    Sabbir Rahman     Nasir Hossain     Rubel Hossain
# 4  Mushfiqur Rahim    Sabbir Rahman     Nasir Hossain  Mashrafe Mortaza
#
#              p10           p11
# 0  Rubel Hossain  Taskin Ahmed
# 1  Rubel Hossain  Taskin Ahmed
# 2  Rubel Hossain  Taskin Ahmed
# 3   Taijul Islam  Taskin Ahmed
# 4  Rubel Hossain  Taskin Ahmed

# %%
del match_data["Day_Night"]
del match_data["Home"]
del match_data["Bat"]
del match_data["Toss"]
del match_data["Opposition"]

# %%
match_data
# Out:
#    Result            p1             p2                     p3  \
# 0     won  Anamul Haque    Tamim Iqbal          Soumya Sarkar
# 1    lost   Tamim Iqbal   Anamul Haque          Soumya Sarkar
# 2     won   Tamim Iqbal    Imrul Kayes          Soumya Sarkar
# 3    lost   Tamim Iqbal    Imrul Kayes          Soumya Sarkar
# 4    lost   Tamim Iqbal    Imrul Kayes          Soumya Sarkar
# ..    ...           ...            ...                    ...
# 73   lost   Tamim Iqbal  Soumya Sarkar        Mohammad Mithun
# 74   lost  Anamul Haque    Tamim Iqbal          Soumya Sarkar
# 75    won     Liton Das    Tamim Iqbal  Najmul Hossain Shanto
# 76    won   Tamim Iqbal      Liton Das  Najmul Hossain Shanto
# 77    won   Tamim Iqbal      Liton Das            Mahmudullah
#
#                  p4               p5               p6                  p7  \
# 0       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# 1     Mominul Haque      Mahmudullah  Shakib Al Hasan     Mushfiqur Rahim
# 2       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# 3       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# 4       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# ..              ...              ...              ...                 ...
# 73  Mushfiqur Rahim      Mahmudullah    Sabbir Rahman    Mosaddek Hossain
# 74  Mushfiqur Rahim  Mohammad Mithun      Mahmudullah       Sabbir Rahman
# 75  Mushfiqur Rahim      Mahmudullah  Mohammad Mithun  Mohammad Saifuddin
# 76  Mushfiqur Rahim      Mahmudullah  Mohammad Mithun  Mehidy Hasan Miraz
# 77     Afif Hossain    Mohammad Naim  Mohammad Mithun  Mehidy Hasan Miraz
#
#                     p8                p9                 p10  \
# 0     Mashrafe Mortaza   Mushfiqur Rahim       Rubel Hossain
# 1        Sabbir Rahman  Mashrafe Mortaza       Rubel Hossain
# 2     Mashrafe Mortaza      Arafat Sunny       Rubel Hossain
# 3        Nasir Hossain     Rubel Hossain        Taijul Islam
# 4        Nasir Hossain  Mashrafe Mortaza       Rubel Hossain
# ..                 ...               ...                 ...
# 73  Mehidy Hasan Miraz      Taijul Islam   Mustafizur Rahman
# 74  Mehidy Hasan Miraz      Taijul Islam       Shafiul Islam
# 75  Mehidy Hasan Miraz  Mashrafe Mortaza        Taijul Islam
# 76    Mashrafe Mortaza      Taijul Islam       Shafiul Islam
# 77    Mashrafe Mortaza      Taijul Islam  Mohammad Saifuddin
#
#                   p11
# 0        Taskin Ahmed
# 1        Taskin Ahmed
# 2        Taskin Ahmed
# 3        Taskin Ahmed
# 4        Taskin Ahmed
# ..                ...
# 73      Shafiul Islam
# 74      Rubel Hossain
# 75  Mustafizur Rahman
# 76    Al-Amin Hossain
# 77  Mustafizur Rahman
#
# [78 rows x 12 columns]

# %%
# convert our pandas dataframe into a list of lists,
player_combo = [] #list of lists match players and result
for i in range(0, 78):
    rowItem = []
    for j in range(0, 12):
        rowItem.append(str(match_data.values[i,j]))
    player_combo.append(rowItem)

# %%
#Creating the dataframe of frequent itemsets
te = TransactionEncoder()
te_ary = te.fit(player_combo).transform(player_combo)
match_df_freq = pd.DataFrame(te_ary, columns=te.columns_)

# %%
match_sup = apriori(match_df_freq, min_support=0.1,use_colnames=True)
print(match_sup)
# Out:
#        support                                           itemsets
# 0     0.128205                                     (Anamul Haque)
# 1     0.102564                                     (Arafat Sunny)
# 2     0.307692                                      (Imrul Kayes)
# 3     0.461538                                        (Liton Das)
# 4     0.948718                                      (Mahmudullah)
# ...        ...                                                ...
# 6634  0.128205  (Mashrafe Mortaza, Sabbir Rahman, Taskin Ahmed...
# 6635  0.128205  (Mashrafe Mortaza, won, Sabbir Rahman, Tamim I...
# 6636  0.102564  (Mashrafe Mortaza, won, Sabbir Rahman, Taskin ...
# 6637  0.102564  (Mashrafe Mortaza, won, Sabbir Rahman, Tamim I...
# 6638  0.102564  (Mashrafe Mortaza, won, Sabbir Rahman, Taskin ...
#
# [6639 rows x 2 columns]

# %%
rules= association_rules(match_sup, metric="lift", min_threshold=1)

# %%
rules
# Out:
#               antecedents                                        consequents  \
# 0          (Anamul Haque)                                      (Mahmudullah)
# 1           (Mahmudullah)                                     (Anamul Haque)
# 2       (Mushfiqur Rahim)                                     (Anamul Haque)
# 3          (Anamul Haque)                                  (Mushfiqur Rahim)
# 4         (Rubel Hossain)                                     (Anamul Haque)
# ...                   ...                                                ...
# 236113      (Tamim Iqbal)  (Mashrafe Mortaza, won, Sabbir Rahman, Taskin ...
# 236114    (Soumya Sarkar)  (Mashrafe Mortaza, won, Sabbir Rahman, Taskin ...
# 236115  (Mushfiqur Rahim)  (Mashrafe Mortaza, won, Sabbir Rahman, Taskin ...
# 236116  (Shakib Al Hasan)  (Mashrafe Mortaza, won, Sabbir Rahman, Taskin ...
# 236117    (Rubel Hossain)  (Mashrafe Mortaza, won, Sabbir Rahman, Taskin ...
#
#         antecedent support  consequent support   support  confidence  \
# 0                 0.128205            0.948718  0.128205    1.000000
# 1                 0.948718            0.128205  0.128205    0.135135
# 2                 0.948718            0.128205  0.128205    0.135135
# 3                 0.128205            0.948718  0.128205    1.000000
# 4                 0.576923            0.128205  0.128205    0.222222
# ...                    ...                 ...       ...         ...
# 236113            0.871795            0.102564  0.102564    0.117647
# 236114            0.641026            0.102564  0.102564    0.160000
# 236115            0.948718            0.102564  0.102564    0.108108
# 236116            0.782051            0.102564  0.102564    0.131148
# 236117            0.576923            0.128205  0.102564    0.177778
#
#             lift  leverage  conviction
# 0       1.054054  0.006575         inf
# 1       1.054054  0.006575    1.008013
# 2       1.054054  0.006575    1.008013
# 3       1.054054  0.006575         inf
# 4       1.733333  0.054241    1.120879
# ...          ...       ...         ...
# 236113  1.147059  0.013149    1.017094
# 236114  1.560000  0.036818    1.068376
# 236115  1.054054  0.005260    1.006216
# 236116  1.278689  0.022354    1.032898
# 236117  1.386667  0.028600    1.060291
#
# [236118 rows x 9 columns]

# %%
won_rules = rules[(rules['consequents'] == {"won"})]

# %%
won_rules
# Out:
#                                               antecedents consequents  \
# 43                                            (Liton Das)       (won)
# 57                                          (Mahmudullah)       (won)
# 66                                     (Mashrafe Mortaza)       (won)
# 85                                      (Mohammad Mithun)       (won)
# 91                                   (Mohammad Saifuddin)       (won)
# ...                                                   ...         ...
# 233162  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 234143  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 234624  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 235107  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 235617  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
#
#         antecedent support  consequent support   support  confidence  \
# 43                0.461538            0.538462  0.269231    0.583333
# 57                0.948718            0.538462  0.512821    0.540541
# 66                0.935897            0.538462  0.525641    0.561644
# 85                0.320513            0.538462  0.179487    0.560000
# 91                0.282051            0.538462  0.166667    0.590909
# ...                    ...                 ...       ...         ...
# 233162            0.141026            0.538462  0.102564    0.727273
# 234143            0.217949            0.538462  0.128205    0.588235
# 234624            0.179487            0.538462  0.102564    0.571429
# 235107            0.128205            0.538462  0.102564    0.800000
# 235617            0.153846            0.538462  0.102564    0.666667
#
#             lift  leverage  conviction
# 43      1.083333  0.020710    1.107692
# 57      1.003861  0.001972    1.004525
# 66      1.043053  0.021696    1.052885
# 85      1.040000  0.006903    1.048951
# 91      1.097403  0.014793    1.128205
# ...          ...       ...         ...
# 233162  1.350649  0.026627    1.692308
# 234143  1.092437  0.010848    1.120879
# 234624  1.061224  0.005917    1.076923
# 235107  1.485714  0.033531    2.307692
# 235617  1.238095  0.019724    1.384615
#
# [901 rows x 9 columns]

# %%
won_rules = won_rules[(won_rules['antecedents'].str.len() > 1)] #Here won_rules['antecedents'] is a frozenset

# %%
won_rules
# Out:
#                                               antecedents consequents  \
# 346                              (Liton Das, Imrul Kayes)       (won)
# 533                              (Liton Das, Mahmudullah)       (won)
# 591                         (Mashrafe Mortaza, Liton Das)       (won)
# 640                       (Liton Das, Mehidy Hasan Miraz)       (won)
# 662                          (Liton Das, Mohammad Mithun)       (won)
# ...                                                   ...         ...
# 233162  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 234143  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 234624  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 235107  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
# 235617  (Mashrafe Mortaza, Sabbir Rahman, Tamim Iqbal,...       (won)
#
#         antecedent support  consequent support   support  confidence  \
# 346               0.166667            0.538462  0.102564    0.615385
# 533               0.410256            0.538462  0.243590    0.593750
# 591               0.461538            0.538462  0.269231    0.583333
# 640               0.282051            0.538462  0.153846    0.545455
# 662               0.192308            0.538462  0.128205    0.666667
# ...                    ...                 ...       ...         ...
# 233162            0.141026            0.538462  0.102564    0.727273
# 234143            0.217949            0.538462  0.128205    0.588235
# 234624            0.179487            0.538462  0.102564    0.571429
# 235107            0.128205            0.538462  0.102564    0.800000
# 235617            0.153846            0.538462  0.102564    0.666667
#
#             lift  leverage  conviction
# 346     1.142857  0.012821    1.200000
# 533     1.102679  0.022682    1.136095
# 591     1.083333  0.020710    1.107692
# 640     1.012987  0.001972    1.015385
# 662     1.238095  0.024655    1.384615
# ...          ...       ...         ...
# 233162  1.350649  0.026627    1.692308
# 234143  1.092437  0.010848    1.120879
# 234624  1.061224  0.005917    1.076923
# 235107  1.485714  0.033531    2.307692
# 235617  1.238095  0.019724    1.384615
#
# [892 rows x 9 columns]

# %%
won_rules.to_csv('bdesh_won_rules.csv')
