# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
import math

# %%
match_data = pd.read_csv('bdesh.csv')

# %%
match_data.head()
# Out:
#   Day_Night Result  Home  Bat  Toss     Opposition            p1  \
# 0        DN    won     0    1   won  v Afghanistan  Anamul Haque
# 1        DN   lost     0    2  lost    v Sri Lanka   Tamim Iqbal
# 2        DN    won     0    1  lost      v England   Tamim Iqbal
# 3        DN   lost     0    1  lost  v New Zealand   Tamim Iqbal
# 4        DN   lost     0    2  lost        v India   Tamim Iqbal
#
#              p2             p3             p4               p5  \
# 0   Tamim Iqbal  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
# 1  Anamul Haque  Soumya Sarkar  Mominul Haque      Mahmudullah
# 2   Imrul Kayes  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
# 3   Imrul Kayes  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
# 4   Imrul Kayes  Soumya Sarkar    Mahmudullah  Shakib Al Hasan
#
#                 p6               p7                p8                p9  \
# 0  Mushfiqur Rahim    Sabbir Rahman  Mashrafe Mortaza   Mushfiqur Rahim
# 1  Shakib Al Hasan  Mushfiqur Rahim     Sabbir Rahman  Mashrafe Mortaza
# 2  Mushfiqur Rahim    Sabbir Rahman  Mashrafe Mortaza      Arafat Sunny
# 3  Mushfiqur Rahim    Sabbir Rahman     Nasir Hossain     Rubel Hossain
# 4  Mushfiqur Rahim    Sabbir Rahman     Nasir Hossain  Mashrafe Mortaza
#
#              p10           p11
# 0  Rubel Hossain  Taskin Ahmed
# 1  Rubel Hossain  Taskin Ahmed
# 2  Rubel Hossain  Taskin Ahmed
# 3   Taijul Islam  Taskin Ahmed
# 4  Rubel Hossain  Taskin Ahmed

# %%
del match_data["Home"]
del match_data["Bat"]
del match_data["Toss"]
del match_data["Opposition"]

# %%
match_data
# Out:
#    Day_Night Result            p1             p2                     p3  \
# 0         DN    won  Anamul Haque    Tamim Iqbal          Soumya Sarkar
# 1         DN   lost   Tamim Iqbal   Anamul Haque          Soumya Sarkar
# 2         DN    won   Tamim Iqbal    Imrul Kayes          Soumya Sarkar
# 3         DN   lost   Tamim Iqbal    Imrul Kayes          Soumya Sarkar
# 4         DN   lost   Tamim Iqbal    Imrul Kayes          Soumya Sarkar
# ..       ...    ...           ...            ...                    ...
# 73        DN   lost   Tamim Iqbal  Soumya Sarkar        Mohammad Mithun
# 74        DN   lost  Anamul Haque    Tamim Iqbal          Soumya Sarkar
# 75        DN    won     Liton Das    Tamim Iqbal  Najmul Hossain Shanto
# 76        DN    won   Tamim Iqbal      Liton Das  Najmul Hossain Shanto
# 77        DN    won   Tamim Iqbal      Liton Das            Mahmudullah
#
#                  p4               p5               p6                  p7  \
# 0       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# 1     Mominul Haque      Mahmudullah  Shakib Al Hasan     Mushfiqur Rahim
# 2       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# 3       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# 4       Mahmudullah  Shakib Al Hasan  Mushfiqur Rahim       Sabbir Rahman
# ..              ...              ...              ...                 ...
# 73  Mushfiqur Rahim      Mahmudullah    Sabbir Rahman    Mosaddek Hossain
# 74  Mushfiqur Rahim  Mohammad Mithun      Mahmudullah       Sabbir Rahman
# 75  Mushfiqur Rahim      Mahmudullah  Mohammad Mithun  Mohammad Saifuddin
# 76  Mushfiqur Rahim      Mahmudullah  Mohammad Mithun  Mehidy Hasan Miraz
# 77     Afif Hossain    Mohammad Naim  Mohammad Mithun  Mehidy Hasan Miraz
#
#                     p8                p9                 p10  \
# 0     Mashrafe Mortaza   Mushfiqur Rahim       Rubel Hossain
# 1        Sabbir Rahman  Mashrafe Mortaza       Rubel Hossain
# 2     Mashrafe Mortaza      Arafat Sunny       Rubel Hossain
# 3        Nasir Hossain     Rubel Hossain        Taijul Islam
# 4        Nasir Hossain  Mashrafe Mortaza       Rubel Hossain
# ..                 ...               ...                 ...
# 73  Mehidy Hasan Miraz      Taijul Islam   Mustafizur Rahman
# 74  Mehidy Hasan Miraz      Taijul Islam       Shafiul Islam
# 75  Mehidy Hasan Miraz  Mashrafe Mortaza        Taijul Islam
# 76    Mashrafe Mortaza      Taijul Islam       Shafiul Islam
# 77    Mashrafe Mortaza      Taijul Islam  Mohammad Saifuddin
#
#                   p11
# 0        Taskin Ahmed
# 1        Taskin Ahmed
# 2        Taskin Ahmed
# 3        Taskin Ahmed
# 4        Taskin Ahmed
# ..                ...
# 73      Shafiul Islam
# 74      Rubel Hossain
# 75  Mustafizur Rahman
# 76    Al-Amin Hossain
# 77  Mustafizur Rahman
#
# [78 rows x 13 columns]

# %%
match_data['Day_Night'].unique()
# Out:
# array(['DN', 'D'], dtype=object)

# %%
player_combo = [] #list of lists match players and result
for i in range(0, 78):
    rowItem = []
    for j in range(0, 13):
        rowItem.append(str(match_data.values[i,j]))
    player_combo.append(rowItem)

# %%
te = TransactionEncoder()
te_ary = te.fit(player_combo).transform(player_combo)
match_df_freq = pd.DataFrame(te_ary, columns=te.columns_)

# %%
match_sup = apriori(match_df_freq, min_support=0.1,use_colnames=True)
match_sup
# Out:
#         support                                           itemsets
# 0      0.128205                                     (Anamul Haque)
# 1      0.102564                                     (Arafat Sunny)
# 2      0.384615                                                (D)
# 3      0.615385                                               (DN)
# 4      0.307692                                      (Imrul Kayes)
# ...         ...                                                ...
# 11272  0.102564  (Nasir Hossain, Sabbir Rahman, Tamim Iqbal, Mu...
# 11273  0.102564  (Sabbir Rahman, Tamim Iqbal, Rubel Hossain, Ta...
# 11274  0.102564  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Must...
# 11275  0.102564  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Must...
# 11276  0.102564  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Rube...
#
# [11277 rows x 2 columns]

# %%
rules= association_rules(match_sup, metric="lift", min_threshold=1)

# %%
rules
# Out:
#               antecedents                                        consequents  \
# 0                    (DN)                                     (Anamul Haque)
# 1          (Anamul Haque)                                               (DN)
# 2           (Mahmudullah)                                     (Anamul Haque)
# 3          (Anamul Haque)                                      (Mahmudullah)
# 4          (Anamul Haque)                                  (Mushfiqur Rahim)
# ...                   ...                                                ...
# 519463     (Taskin Ahmed)  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Rube...
# 519464  (Mushfiqur Rahim)  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Rube...
# 519465               (DN)  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Rube...
# 519466    (Soumya Sarkar)  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Rube...
# 519467  (Shakib Al Hasan)  (Sabbir Rahman, Mahmudullah, Tamim Iqbal, Rube...
#
#         antecedent support  consequent support   support  confidence  \
# 0                 0.615385            0.128205  0.102564    0.166667
# 1                 0.128205            0.615385  0.102564    0.800000
# 2                 0.948718            0.128205  0.128205    0.135135
# 3                 0.128205            0.948718  0.128205    1.000000
# 4                 0.128205            0.948718  0.128205    1.000000
# ...                    ...                 ...       ...         ...
# 519463            0.333333            0.128205  0.102564    0.307692
# 519464            0.948718            0.102564  0.102564    0.108108
# 519465            0.615385            0.128205  0.102564    0.166667
# 519466            0.641026            0.102564  0.102564    0.160000
# 519467            0.782051            0.102564  0.102564    0.131148
#
#             lift  leverage  conviction
# 0       1.300000  0.023669    1.046154
# 1       1.300000  0.023669    1.923077
# 2       1.054054  0.006575    1.008013
# 3       1.054054  0.006575         inf
# 4       1.054054  0.006575         inf
# ...          ...       ...         ...
# 519463  2.400000  0.059829    1.259259
# 519464  1.054054  0.005260    1.006216
# 519465  1.300000  0.023669    1.046154
# 519466  1.560000  0.036818    1.068376
# 519467  1.278689  0.022354    1.032898
#
# [519468 rows x 9 columns]

# %%
won_rules = rules[(rules['consequents'] == {"won"})]

# %%
won_rules
# Out:
#                                               antecedents consequents  \
# 62                                                   (DN)       (won)
# 89                                            (Liton Das)       (won)
# 102                                         (Mahmudullah)       (won)
# 112                                    (Mashrafe Mortaza)       (won)
# 131                                     (Mohammad Mithun)       (won)
# ...                                                   ...         ...
# 513515  (Nasir Hossain, Mahmudullah, Tamim Iqbal, Rube...       (won)
# 514497  (Mahmudullah, Tamim Iqbal, Rubel Hossain, Mush...       (won)
# 514977  (Mahmudullah, Tamim Iqbal, Mushfiqur Rahim, Ta...       (won)
# 515460  (Nasir Hossain, Tamim Iqbal, Mustafizur Rahman...       (won)
# 515969  (Tamim Iqbal, Rubel Hossain, Mushfiqur Rahim, ...       (won)
#
#         antecedent support  consequent support   support  confidence  \
# 62                0.615385            0.538462  0.371795    0.604167
# 89                0.461538            0.538462  0.269231    0.583333
# 102               0.948718            0.538462  0.512821    0.540541
# 112               0.935897            0.538462  0.525641    0.561644
# 131               0.320513            0.538462  0.179487    0.560000
# ...                    ...                 ...       ...         ...
# 513515            0.141026            0.538462  0.102564    0.727273
# 514497            0.217949            0.538462  0.128205    0.588235
# 514977            0.179487            0.538462  0.102564    0.571429
# 515460            0.128205            0.538462  0.102564    0.800000
# 515969            0.153846            0.538462  0.102564    0.666667
#
#             lift  leverage  conviction
# 62      1.122024  0.040434    1.165992
# 89      1.083333  0.020710    1.107692
# 102     1.003861  0.001972    1.004525
# 112     1.043053  0.021696    1.052885
# 131     1.040000  0.006903    1.048951
# ...          ...       ...         ...
# 513515  1.350649  0.026627    1.692308
# 514497  1.092437  0.010848    1.120879
# 514977  1.061224  0.005917    1.076923
# 515460  1.485714  0.033531    2.307692
# 515969  1.238095  0.019724    1.384615
#
# [1633 rows x 9 columns]

# %%
won_rules.values[0,:]
# Out:
# array([frozenset({'DN'}), frozenset({'won'}), 0.6153846153846154,
#        0.5384615384615384, 0.3717948717948718, 0.6041666666666666,
#        1.1220238095238095, 0.04043392504930965, 1.165991902834008],
#       dtype=object)

# %%
col_names = ["antecedents","consequents","antecedent support","consequent support","support","confidence","lift","leverage","conviction"]
DN_won_rules = pd.DataFrame(columns = col_names)

# %%
i = 0
for x in won_rules['antecedents']:
    for y in x:
        if y == 'DN':
            #print(won_rules.values[i,0])
            DN_won_rules = DN_won_rules.append({'antecedents':won_rules.values[i,0],"consequents":won_rules.values[i,1],"antecedent support":won_rules.values[i,2],"consequent support":won_rules.values[i,3],"support":won_rules.values[i,4],"confidence":won_rules.values[i,5],"lift":won_rules.values[i,6],"leverage":won_rules.values[i,7],"conviction":won_rules.values[i,8]},ignore_index=True)
    i = i + 1

# %%
DN_won_rules
# Out:
#                                            antecedents consequents  \
# 0                                                 (DN)       (won)
# 1                                    (DN, Imrul Kayes)       (won)
# 2                                      (DN, Liton Das)       (won)
# 3                                    (DN, Mahmudullah)       (won)
# 4                               (Mashrafe Mortaza, DN)       (won)
# ..                                                 ...         ...
# 705  (Nasir Hossain, Tamim Iqbal, Mustafizur Rahman...       (won)
# 706  (Nasir Hossain, Tamim Iqbal, Rubel Hossain, Mu...       (won)
# 707  (Tamim Iqbal, Rubel Hossain, Mushfiqur Rahim, ...       (won)
# 708  (Tamim Iqbal, Mushfiqur Rahim, Taskin Ahmed, D...       (won)
# 709  (Tamim Iqbal, Rubel Hossain, Mushfiqur Rahim, ...       (won)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.615385            0.538462  0.371795    0.604167  1.122024
# 1              0.192308            0.538462  0.128205    0.666667  1.238095
# 2              0.294872            0.538462  0.217949    0.739130  1.372671
# 3              0.576923            0.538462  0.346154    0.600000  1.114286
# 4              0.551282            0.538462  0.358974    0.651163  1.209302
# ..                  ...                 ...       ...         ...       ...
# 705            0.141026            0.538462  0.102564    0.727273  1.350649
# 706            0.153846            0.538462  0.115385    0.750000  1.392857
# 707            0.166667            0.538462  0.115385    0.692308  1.285714
# 708            0.153846            0.538462  0.115385    0.750000  1.392857
# 709            0.153846            0.538462  0.102564    0.666667  1.238095
#
#      leverage  conviction
# 0    0.040434    1.165992
# 1    0.024655    1.384615
# 2    0.059172    1.769231
# 3    0.035503    1.153846
# 4    0.062130    1.323077
# ..        ...         ...
# 705  0.026627    1.692308
# 706  0.032544    1.846154
# 707  0.025641    1.500000
# 708  0.032544    1.846154
# 709  0.019724    1.384615
#
# [710 rows x 9 columns]

# %%
DN_won_rules.to_csv('DN_won_rules.csv')

# %%
col_names = ["antecedents","consequents","antecedent support","consequent support","support","confidence","lift","leverage","conviction"]
D_won_rules = pd.DataFrame(columns = col_names)

# %%
i = 0
for x in won_rules['antecedents']:
    for y in x:
        if y == 'D':
            #print(won_rules.values[i,0])
            D_won_rules = D_won_rules.append({'antecedents':won_rules.values[i,0],"consequents":won_rules.values[i,1],"antecedent support":won_rules.values[i,2],"consequent support":won_rules.values[i,3],"support":won_rules.values[i,4],"confidence":won_rules.values[i,5],"lift":won_rules.values[i,6],"leverage":won_rules.values[i,7],"conviction":won_rules.values[i,8]},ignore_index=True)
    i = i + 1

# %%
D_won_rules#no rules
# Out:
#                                           antecedents consequents  \
# 0              (Mosaddek Hossain, D, Mushfiqur Rahim)       (won)
# 1   (Mosaddek Hossain, Mahmudullah, D, Mushfiqur R...       (won)
# 2   (Mashrafe Mortaza, Mosaddek Hossain, D, Mushfi...       (won)
# 3   (Tamim Iqbal, Mosaddek Hossain, D, Mushfiqur R...       (won)
# 4   (Mahmudullah, Mushfiqur Rahim, Mosaddek Hossai...       (won)
# 5   (Mahmudullah, Mustafizur Rahman, Mushfiqur Rah...       (won)
# 6   (Mahmudullah, Mushfiqur Rahim, Mosaddek Hossai...       (won)
# 7   (Mahmudullah, Tamim Iqbal, Mushfiqur Rahim, Mo...       (won)
# 8   (Mahmudullah, Mustafizur Rahman, Mushfiqur Rah...       (won)
# 9   (Mahmudullah, Tamim Iqbal, Mushfiqur Rahim, Sh...       (won)
# 10  (Tamim Iqbal, Mushfiqur Rahim, Mosaddek Hossai...       (won)
# 11  (Mahmudullah, Mustafizur Rahman, Mushfiqur Rah...       (won)
# 12  (Mahmudullah, Mushfiqur Rahim, Mosaddek Hossai...       (won)
# 13  (Mahmudullah, Tamim Iqbal, Mushfiqur Rahim, Mo...       (won)
# 14  (Mahmudullah, Mustafizur Rahman, Mushfiqur Rah...       (won)
# 15  (Mahmudullah, Tamim Iqbal, Mushfiqur Rahim, Sh...       (won)
# 16  (Mahmudullah, Tamim Iqbal, Mustafizur Rahman, ...       (won)
# 17  (Mahmudullah, Tamim Iqbal, Mushfiqur Rahim, Mo...       (won)
# 18  (Mahmudullah, Tamim Iqbal, Mustafizur Rahman, ...       (won)
# 19  (Mahmudullah, Tamim Iqbal, Mustafizur Rahman, ...       (won)
# 20  (Mahmudullah, Tamim Iqbal, Mushfiqur Rahim, Mo...       (won)
# 21  (Mahmudullah, Tamim Iqbal, Mustafizur Rahman, ...       (won)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.230769            0.538462  0.128205    0.555556  1.031746
# 1             0.217949            0.538462  0.128205    0.588235  1.092437
# 2             0.230769            0.538462  0.128205    0.555556  1.031746
# 3             0.230769            0.538462  0.128205    0.555556  1.031746
# 4             0.217949            0.538462  0.128205    0.588235  1.092437
# 5             0.205128            0.538462  0.115385    0.562500  1.044643
# 6             0.205128            0.538462  0.115385    0.562500  1.044643
# 7             0.217949            0.538462  0.128205    0.588235  1.092437
# 8             0.230769            0.538462  0.128205    0.555556  1.031746
# 9             0.256410            0.538462  0.141026    0.550000  1.021429
# 10            0.230769            0.538462  0.128205    0.555556  1.031746
# 11            0.205128            0.538462  0.115385    0.562500  1.044643
# 12            0.205128            0.538462  0.115385    0.562500  1.044643
# 13            0.217949            0.538462  0.128205    0.588235  1.092437
# 14            0.230769            0.538462  0.128205    0.555556  1.031746
# 15            0.256410            0.538462  0.141026    0.550000  1.021429
# 16            0.205128            0.538462  0.115385    0.562500  1.044643
# 17            0.205128            0.538462  0.115385    0.562500  1.044643
# 18            0.230769            0.538462  0.128205    0.555556  1.031746
# 19            0.205128            0.538462  0.115385    0.562500  1.044643
# 20            0.205128            0.538462  0.115385    0.562500  1.044643
# 21            0.230769            0.538462  0.128205    0.555556  1.031746
#
#     leverage  conviction
# 0   0.003945    1.038462
# 1   0.010848    1.120879
# 2   0.003945    1.038462
# 3   0.003945    1.038462
# 4   0.010848    1.120879
# 5   0.004931    1.054945
# 6   0.004931    1.054945
# 7   0.010848    1.120879
# 8   0.003945    1.038462
# 9   0.002959    1.025641
# 10  0.003945    1.038462
# 11  0.004931    1.054945
# 12  0.004931    1.054945
# 13  0.010848    1.120879
# 14  0.003945    1.038462
# 15  0.002959    1.025641
# 16  0.004931    1.054945
# 17  0.004931    1.054945
# 18  0.003945    1.038462
# 19  0.004931    1.054945
# 20  0.004931    1.054945
# 21  0.003945    1.038462

# %%
D_won_rules.to_csv('D_won_rules.csv')
