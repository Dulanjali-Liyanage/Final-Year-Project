# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
import math

# %%
match_data = pd.read_csv('aus_data.csv')

# %%
match_data.head()
# Out:
#   Day_Night Result  Home  Bat  Toss Opposition         p1         p2  \
# 0        DN    won     1    2  lost  v England  DA Warner   AJ Finch
# 1        DN    won     1    2  lost    v India   AJ Finch  DA Warner
# 2        DN    won     1    2   won  v England   AJ Finch   SE Marsh
# 3         D    won     1    1  lost  v England   AJ Finch  DA Warner
# 4         D    won     1    1  lost  v England  DA Warner   AJ Finch
#
#           p3         p4          p5           p6         p7            p8  \
# 0  SR Watson  SPD Smith   GJ Bailey   GJ Maxwell  BJ Haddin   JP Faulkner
# 1  SR Watson  SPD Smith  GJ Maxwell    GJ Bailey  BJ Haddin   JP Faulkner
# 2  SPD Smith   CL White  GJ Maxwell  JP Faulkner  BJ Haddin  MC Henriques
# 3  SPD Smith  GJ Bailey  GJ Maxwell     MR Marsh  BJ Haddin   JP Faulkner
# 4  SR Watson  SPD Smith   GJ Bailey   GJ Maxwell   MR Marsh     BJ Haddin
#
#            p9         p10           p11
# 0    MA Starc  PJ Cummins    XJ Doherty
# 1    MA Starc  PJ Cummins     GS Sandhu
# 2    MA Starc  PJ Cummins     GS Sandhu
# 3  MG Johnson    MA Starc  JR Hazlewood
# 4  MG Johnson    MA Starc  JR Hazlewood

# %%
del match_data["Home"]
del match_data["Bat"]
del match_data["Toss"]
del match_data["Opposition"]

# %%
match_data
# Out:
#     Day_Night Result         p1         p2          p3             p4  \
# 0          DN    won  DA Warner   AJ Finch   SR Watson      SPD Smith
# 1          DN    won   AJ Finch  DA Warner   SR Watson      SPD Smith
# 2          DN    won   AJ Finch   SE Marsh   SPD Smith       CL White
# 3           D    won   AJ Finch  DA Warner   SPD Smith      GJ Bailey
# 4           D    won  DA Warner   AJ Finch   SR Watson      SPD Smith
# ..        ...    ...        ...        ...         ...            ...
# 99          D   lost  DA Warner   AJ Finch   SPD Smith  M Labuschagne
# 100        DN    won  DA Warner   AJ Finch   SPD Smith      DJM Short
# 101        DN    won  DA Warner   AJ Finch  MP Stoinis  M Labuschagne
# 102        DN   lost  DA Warner   AJ Finch  MP Stoinis  M Labuschagne
# 103        DN    won  DA Warner   AJ Finch  MP Stoinis  M Labuschagne
#
#                 p5           p6          p7             p8             p9  \
# 0        GJ Bailey   GJ Maxwell   BJ Haddin    JP Faulkner       MA Starc
# 1       GJ Maxwell    GJ Bailey   BJ Haddin    JP Faulkner       MA Starc
# 2       GJ Maxwell  JP Faulkner   BJ Haddin   MC Henriques       MA Starc
# 3       GJ Maxwell     MR Marsh   BJ Haddin    JP Faulkner     MG Johnson
# 4        GJ Bailey   GJ Maxwell    MR Marsh      BJ Haddin     MG Johnson
# ..             ...          ...         ...            ...            ...
# 99       DJM Short     MR Marsh    AT Carey  JA Richardson  KW Richardson
# 100  M Labuschagne     MR Marsh    AT Carey     PJ Cummins       MA Starc
# 101       MR Marsh     AT Carey  GJ Maxwell     PJ Cummins       MA Starc
# 102       MR Marsh     AT Carey  GJ Maxwell     PJ Cummins       MA Starc
# 103       MR Marsh     AT Carey  GJ Maxwell     PJ Cummins       MA Starc
#
#             p10           p11
# 0    PJ Cummins    XJ Doherty
# 1    PJ Cummins     GS Sandhu
# 2    PJ Cummins     GS Sandhu
# 3      MA Starc  JR Hazlewood
# 4      MA Starc  JR Hazlewood
# ..          ...           ...
# 99      A Zampa  JR Hazlewood
# 100     A Zampa  JR Hazlewood
# 101     A Zampa  JR Hazlewood
# 102     A Zampa  JR Hazlewood
# 103     A Zampa  JR Hazlewood
#
# [104 rows x 13 columns]

# %%
match_data['Day_Night'].unique()
# Out:
# array(['DN', 'D'], dtype=object)

# %%
player_combo = [] #list of lists match players and result
for i in range(0, 104):
    rowItem = []
    for j in range(0, 13):
        rowItem.append(str(match_data.values[i,j]))
    player_combo.append(rowItem)

# %%
te = TransactionEncoder()
te_ary = te.fit(player_combo).transform(player_combo)
match_df_freq = pd.DataFrame(te_ary, columns=te.columns_)

# %%
match_sup = apriori(match_df_freq, min_support=0.1,use_colnames=True)
match_sup
# Out:
#        support                                           itemsets
# 0     0.548077                                          (A Zampa)
# 1     0.125000                                          (AC Agar)
# 2     0.846154                                         (AJ Finch)
# 3     0.375000                                         (AT Carey)
# 4     0.105769                                        (BJ Haddin)
# ...        ...                                                ...
# 2772  0.105769  (AT Carey, MA Starc, PJ Cummins, GJ Maxwell, A...
# 2773  0.115385  (AT Carey, UT Khawaja, DN, GJ Maxwell, AJ Finc...
# 2774  0.115385  (AT Carey, UT Khawaja, DN, GJ Maxwell, PSP Han...
# 2775  0.105769  (won, DN, SPD Smith, AJ Finch, JP Faulkner, MA...
# 2776  0.105769  (won, DN, SPD Smith, AJ Finch, JR Hazlewood, M...
#
# [2777 rows x 2 columns]

# %%
rules= association_rules(match_sup, metric="lift", min_threshold=1)

# %%
rules
# Out:
#           antecedents                                        consequents  \
# 0          (AJ Finch)                                          (A Zampa)
# 1           (A Zampa)                                         (AJ Finch)
# 2          (AT Carey)                                          (A Zampa)
# 3           (A Zampa)                                         (AT Carey)
# 4           (A Zampa)                                        (DA Warner)
# ...               ...                                                ...
# 38897     (SPD Smith)  (won, DN, AJ Finch, JR Hazlewood, MA Starc, DA...
# 38898      (AJ Finch)  (won, DN, SPD Smith, JR Hazlewood, MA Starc, D...
# 38899  (JR Hazlewood)  (won, DN, SPD Smith, AJ Finch, MA Starc, DA Wa...
# 38900      (MA Starc)  (won, DN, SPD Smith, AJ Finch, JR Hazlewood, D...
# 38901     (DA Warner)  (won, DN, SPD Smith, AJ Finch, JR Hazlewood, M...
#
#        antecedent support  consequent support   support  confidence      lift  \
# 0                0.846154            0.548077  0.471154    0.556818  1.015949
# 1                0.548077            0.846154  0.471154    0.859649  1.015949
# 2                0.375000            0.548077  0.259615    0.692308  1.263158
# 3                0.548077            0.375000  0.259615    0.473684  1.263158
# 4                0.548077            0.692308  0.394231    0.719298  1.038986
# ...                   ...                 ...       ...         ...       ...
# 38897            0.721154            0.134615  0.105769    0.146667  1.089524
# 38898            0.846154            0.125000  0.105769    0.125000  1.000000
# 38899            0.394231            0.153846  0.105769    0.268293  1.743902
# 38900            0.586538            0.105769  0.105769    0.180328  1.704918
# 38901            0.692308            0.125000  0.105769    0.152778  1.222222
#
#        leverage  conviction
# 0      0.007396    1.019724
# 1      0.007396    1.096154
# 2      0.054087    1.468750
# 3      0.054087    1.187500
# 4      0.014793    1.096154
# ...         ...         ...
# 38897  0.008691    1.014123
# 38898  0.000000    1.000000
# 38899  0.045118    1.156410
# 38900  0.043732    1.090962
# 38901  0.019231    1.032787
#
# [38902 rows x 9 columns]

# %%
won_rules = rules[(rules['consequents'] == {"won"})]

# %%
won_rules
# Out:
#                                              antecedents consequents  \
# 123                                          (DA Warner)       (won)
# 145                                                 (DN)       (won)
# 162                                          (GJ Bailey)       (won)
# 187                                         (GJ Maxwell)       (won)
# 201                                        (JP Faulkner)       (won)
# ...                                                  ...         ...
# 37775  (PJ Cummins, GJ Maxwell, SPD Smith, MA Starc, ...       (won)
# 37837  (DN, GJ Maxwell, SPD Smith, JP Faulkner, MA St...       (won)
# 38151  (AT Carey, DN, GJ Maxwell, AJ Finch, A Zampa, ...       (won)
# 38656  (DN, SPD Smith, AJ Finch, JP Faulkner, MA Star...       (won)
# 38782  (DN, SPD Smith, AJ Finch, JR Hazlewood, MA Sta...       (won)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 123              0.692308            0.557692  0.403846    0.583333  1.045977
# 145              0.730769            0.557692  0.432692    0.592105  1.061706
# 162              0.346154            0.557692  0.230769    0.666667  1.195402
# 187              0.682692            0.557692  0.423077    0.619718  1.111219
# 201              0.317308            0.557692  0.230769    0.727273  1.304075
# ...                   ...                 ...       ...         ...       ...
# 37775            0.201923            0.557692  0.144231    0.714286  1.280788
# 37837            0.115385            0.557692  0.105769    0.916667  1.643678
# 38151            0.153846            0.557692  0.105769    0.687500  1.232759
# 38656            0.115385            0.557692  0.105769    0.916667  1.643678
# 38782            0.125000            0.557692  0.105769    0.846154  1.517241
#
#        leverage  conviction
# 123    0.017751    1.061538
# 145    0.025148    1.084367
# 162    0.037722    1.326923
# 187    0.042345    1.163105
# 201    0.053809    1.621795
# ...         ...         ...
# 37775  0.031620    1.548077
# 37837  0.041420    5.307692
# 38151  0.019970    1.415385
# 38656  0.041420    5.307692
# 38782  0.036058    2.875000
#
# [528 rows x 9 columns]

# %%
won_rules.values[0,:]
# Out:
# array([frozenset({'DA Warner'}), frozenset({'won'}), 0.6923076923076923,
#        0.5576923076923077, 0.40384615384615385, 0.5833333333333334,
#        1.0459770114942528, 0.017751479289940808, 1.0615384615384615],
#       dtype=object)

# %%
col_names = ["antecedents","consequents","antecedent support","consequent support","support","confidence","lift","leverage","conviction"]
DN_won_rules = pd.DataFrame(columns = col_names)

# %%
i = 0
for x in won_rules['antecedents']:
    for y in x:
        if y == 'DN':
            #print(won_rules.values[i,0])
            DN_won_rules = DN_won_rules.append({'antecedents':won_rules.values[i,0],"consequents":won_rules.values[i,1],"antecedent support":won_rules.values[i,2],"consequent support":won_rules.values[i,3],"support":won_rules.values[i,4],"confidence":won_rules.values[i,5],"lift":won_rules.values[i,6],"leverage":won_rules.values[i,7],"conviction":won_rules.values[i,8]},ignore_index=True)
    i = i + 1

# %%
DN_won_rules
# Out:
#                                            antecedents consequents  \
# 0                                                 (DN)       (won)
# 1                                        (A Zampa, DN)       (won)
# 2                                       (AJ Finch, DN)       (won)
# 3                                       (AT Carey, DN)       (won)
# 4                                      (DA Warner, DN)       (won)
# ..                                                 ...         ...
# 194   (DN, PJ Cummins, SPD Smith, MA Starc, DA Warner)       (won)
# 195  (DN, GJ Maxwell, SPD Smith, JP Faulkner, MA St...       (won)
# 196  (AT Carey, DN, GJ Maxwell, AJ Finch, A Zampa, ...       (won)
# 197  (DN, SPD Smith, AJ Finch, JP Faulkner, MA Star...       (won)
# 198  (DN, SPD Smith, AJ Finch, JR Hazlewood, MA Sta...       (won)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.730769            0.557692  0.432692    0.592105  1.061706
# 1              0.423077            0.557692  0.250000    0.590909  1.059561
# 2              0.615385            0.557692  0.365385    0.593750  1.064655
# 3              0.250000            0.557692  0.144231    0.576923  1.034483
# 4              0.490385            0.557692  0.288462    0.588235  1.054767
# ..                  ...                 ...       ...         ...       ...
# 194            0.182692            0.557692  0.115385    0.631579  1.132486
# 195            0.115385            0.557692  0.105769    0.916667  1.643678
# 196            0.153846            0.557692  0.105769    0.687500  1.232759
# 197            0.115385            0.557692  0.105769    0.916667  1.643678
# 198            0.125000            0.557692  0.105769    0.846154  1.517241
#
#      leverage  conviction
# 0    0.025148    1.084367
# 1    0.014053    1.081197
# 2    0.022189    1.088757
# 3    0.004808    1.045455
# 4    0.014978    1.074176
# ..        ...         ...
# 194  0.013499    1.200549
# 195  0.041420    5.307692
# 196  0.019970    1.415385
# 197  0.041420    5.307692
# 198  0.036058    2.875000
#
# [199 rows x 9 columns]

# %%
DN_won_rules.to_csv('DN_won_rules.csv')

# %%
col_names = ["antecedents","consequents","antecedent support","consequent support","support","confidence","lift","leverage","conviction"]
D_won_rules = pd.DataFrame(columns = col_names)

# %%
i = 0
for x in won_rules['antecedents']:
    for y in x:
        if y == 'D':
            #print(won_rules.values[i,0])
            D_won_rules = D_won_rules.append({'antecedents':won_rules.values[i,0],"consequents":won_rules.values[i,1],"antecedent support":won_rules.values[i,2],"consequent support":won_rules.values[i,3],"support":won_rules.values[i,4],"confidence":won_rules.values[i,5],"lift":won_rules.values[i,6],"leverage":won_rules.values[i,7],"conviction":won_rules.values[i,8]},ignore_index=True)
    i = i + 1

# %%
D_won_rules#no rules
# Out:
#                   antecedents consequents  antecedent support  \
# 0              (D, DA Warner)       (won)            0.201923
# 1              (D, SPD Smith)       (won)            0.221154
# 2   (D, SPD Smith, DA Warner)       (won)            0.201923
# 3  (D, SPD Smith, GJ Maxwell)       (won)            0.153846
# 4    (D, MA Starc, SPD Smith)       (won)            0.163462
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.557692  0.115385    0.571429  1.024631  0.002774    1.032051
# 1            0.557692  0.125000    0.565217  1.013493  0.001664    1.017308
# 2            0.557692  0.115385    0.571429  1.024631  0.002774    1.032051
# 3            0.557692  0.105769    0.687500  1.232759  0.019970    1.415385
# 4            0.557692  0.105769    0.647059  1.160243  0.014608    1.253205

# %%
D_won_rules.to_csv('D_won_rules.csv')
