# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
import math

# %%
match_data = pd.read_csv('aus_data.csv')

# %%
match_data.head()
# Out:
#   Day_Night Result  Home  Bat  Toss Opposition         p1         p2  \
# 0        DN    won     1    2  lost  v England  DA Warner   AJ Finch
# 1        DN    won     1    2  lost    v India   AJ Finch  DA Warner
# 2        DN    won     1    2   won  v England   AJ Finch   SE Marsh
# 3         D    won     1    1  lost  v England   AJ Finch  DA Warner
# 4         D    won     1    1  lost  v England  DA Warner   AJ Finch
#
#           p3         p4          p5           p6         p7            p8  \
# 0  SR Watson  SPD Smith   GJ Bailey   GJ Maxwell  BJ Haddin   JP Faulkner
# 1  SR Watson  SPD Smith  GJ Maxwell    GJ Bailey  BJ Haddin   JP Faulkner
# 2  SPD Smith   CL White  GJ Maxwell  JP Faulkner  BJ Haddin  MC Henriques
# 3  SPD Smith  GJ Bailey  GJ Maxwell     MR Marsh  BJ Haddin   JP Faulkner
# 4  SR Watson  SPD Smith   GJ Bailey   GJ Maxwell   MR Marsh     BJ Haddin
#
#            p9         p10           p11
# 0    MA Starc  PJ Cummins    XJ Doherty
# 1    MA Starc  PJ Cummins     GS Sandhu
# 2    MA Starc  PJ Cummins     GS Sandhu
# 3  MG Johnson    MA Starc  JR Hazlewood
# 4  MG Johnson    MA Starc  JR Hazlewood

# %%
del match_data["Day_Night"]
del match_data["Home"]
del match_data["Bat"]
del match_data["Toss"]
del match_data["Opposition"]

# %%
match_data
# Out:
#     Result         p1         p2          p3             p4             p5  \
# 0      won  DA Warner   AJ Finch   SR Watson      SPD Smith      GJ Bailey
# 1      won   AJ Finch  DA Warner   SR Watson      SPD Smith     GJ Maxwell
# 2      won   AJ Finch   SE Marsh   SPD Smith       CL White     GJ Maxwell
# 3      won   AJ Finch  DA Warner   SPD Smith      GJ Bailey     GJ Maxwell
# 4      won  DA Warner   AJ Finch   SR Watson      SPD Smith      GJ Bailey
# ..     ...        ...        ...         ...            ...            ...
# 99    lost  DA Warner   AJ Finch   SPD Smith  M Labuschagne      DJM Short
# 100    won  DA Warner   AJ Finch   SPD Smith      DJM Short  M Labuschagne
# 101    won  DA Warner   AJ Finch  MP Stoinis  M Labuschagne       MR Marsh
# 102   lost  DA Warner   AJ Finch  MP Stoinis  M Labuschagne       MR Marsh
# 103    won  DA Warner   AJ Finch  MP Stoinis  M Labuschagne       MR Marsh
#
#               p6          p7             p8             p9         p10  \
# 0     GJ Maxwell   BJ Haddin    JP Faulkner       MA Starc  PJ Cummins
# 1      GJ Bailey   BJ Haddin    JP Faulkner       MA Starc  PJ Cummins
# 2    JP Faulkner   BJ Haddin   MC Henriques       MA Starc  PJ Cummins
# 3       MR Marsh   BJ Haddin    JP Faulkner     MG Johnson    MA Starc
# 4     GJ Maxwell    MR Marsh      BJ Haddin     MG Johnson    MA Starc
# ..           ...         ...            ...            ...         ...
# 99      MR Marsh    AT Carey  JA Richardson  KW Richardson     A Zampa
# 100     MR Marsh    AT Carey     PJ Cummins       MA Starc     A Zampa
# 101     AT Carey  GJ Maxwell     PJ Cummins       MA Starc     A Zampa
# 102     AT Carey  GJ Maxwell     PJ Cummins       MA Starc     A Zampa
# 103     AT Carey  GJ Maxwell     PJ Cummins       MA Starc     A Zampa
#
#               p11
# 0      XJ Doherty
# 1       GS Sandhu
# 2       GS Sandhu
# 3    JR Hazlewood
# 4    JR Hazlewood
# ..            ...
# 99   JR Hazlewood
# 100  JR Hazlewood
# 101  JR Hazlewood
# 102  JR Hazlewood
# 103  JR Hazlewood
#
# [104 rows x 12 columns]

# %%
# convert our pandas dataframe into a list of lists,
player_combo = [] #list of lists match players and result
for i in range(0, 104):
    rowItem = []
    for j in range(0, 12):
        rowItem.append(str(match_data.values[i,j]))
    player_combo.append(rowItem)

# %%
#Creating the dataframe of frequent itemsets
te = TransactionEncoder()
te_ary = te.fit(player_combo).transform(player_combo)
match_df_freq = pd.DataFrame(te_ary, columns=te.columns_)

# %%
match_sup = apriori(match_df_freq, min_support=0.1,use_colnames=True)
print(match_sup)
# Out:
#        support                                           itemsets
# 0     0.548077                                          (A Zampa)
# 1     0.125000                                          (AC Agar)
# 2     0.846154                                         (AJ Finch)
# 3     0.375000                                         (AT Carey)
# 4     0.105769                                        (BJ Haddin)
# ...        ...                                                ...
# 1753  0.105769  (MA Starc, PJ Cummins, DA Warner, MP Stoinis, ...
# 1754  0.105769  (GJ Bailey, MS Wade, MR Marsh, DA Warner, SPD ...
# 1755  0.105769  (MA Starc, PJ Cummins, DA Warner, SPD Smith, U...
# 1756  0.144231  (MA Starc, PJ Cummins, DA Warner, SPD Smith, w...
# 1757  0.105769  (AJ Finch, MA Starc, PJ Cummins, DA Warner, MP...
#
# [1758 rows x 2 columns]

# %%
rules= association_rules(match_sup, metric="lift", min_threshold=1)

# %%
rules
# Out:
#         antecedents                                        consequents  \
# 0        (AJ Finch)                                          (A Zampa)
# 1         (A Zampa)                                         (AJ Finch)
# 2         (A Zampa)                                         (AT Carey)
# 3        (AT Carey)                                          (A Zampa)
# 4       (DA Warner)                                          (A Zampa)
# ...             ...                                                ...
# 20141  (PJ Cummins)  (AJ Finch, MA Starc, DA Warner, MP Stoinis, GJ...
# 20142   (DA Warner)  (AJ Finch, MA Starc, PJ Cummins, MP Stoinis, G...
# 20143  (MP Stoinis)  (AJ Finch, MA Starc, PJ Cummins, DA Warner, GJ...
# 20144  (GJ Maxwell)  (AJ Finch, MA Starc, PJ Cummins, DA Warner, MP...
# 20145    (AT Carey)  (AJ Finch, MA Starc, PJ Cummins, DA Warner, MP...
#
#        antecedent support  consequent support   support  confidence      lift  \
# 0                0.846154            0.548077  0.471154    0.556818  1.015949
# 1                0.548077            0.846154  0.471154    0.859649  1.015949
# 2                0.548077            0.375000  0.259615    0.473684  1.263158
# 3                0.375000            0.548077  0.259615    0.692308  1.263158
# 4                0.692308            0.548077  0.394231    0.569444  1.038986
# ...                   ...                 ...       ...         ...       ...
# 20141            0.538462            0.105769  0.105769    0.196429  1.857143
# 20142            0.692308            0.134615  0.105769    0.152778  1.134921
# 20143            0.423077            0.125000  0.105769    0.250000  2.000000
# 20144            0.682692            0.105769  0.105769    0.154930  1.464789
# 20145            0.375000            0.105769  0.105769    0.282051  2.666667
#
#        leverage  conviction
# 0      0.007396    1.019724
# 1      0.007396    1.096154
# 2      0.054087    1.187500
# 3      0.054087    1.468750
# 4      0.014793    1.049628
# ...         ...         ...
# 20141  0.048817    1.112821
# 20142  0.012574    1.021438
# 20143  0.052885    1.166667
# 20144  0.033561    1.058173
# 20145  0.066106    1.245536
#
# [20146 rows x 9 columns]

# %%
won_rules = rules[(rules['consequents'] == {"won"})]

# %%
won_rules
# Out:
#                                              antecedents consequents  \
# 103                                          (DA Warner)       (won)
# 121                                          (GJ Bailey)       (won)
# 145                                         (GJ Maxwell)       (won)
# 159                                        (JP Faulkner)       (won)
# 170                                       (JR Hazlewood)       (won)
# ...                                                  ...         ...
# 19610  (AJ Finch, MA Starc, PJ Cummins, DA Warner, SP...       (won)
# 19669  (AJ Finch, MA Starc, PJ Cummins, SPD Smith, GJ...       (won)
# 19710  (JR Hazlewood, AJ Finch, MR Marsh, MA Starc, S...       (won)
# 19834  (GJ Bailey, MS Wade, MR Marsh, DA Warner, SPD ...       (won)
# 19959  (MA Starc, PJ Cummins, DA Warner, SPD Smith, G...       (won)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 103              0.692308            0.557692  0.403846    0.583333  1.045977
# 121              0.346154            0.557692  0.230769    0.666667  1.195402
# 145              0.682692            0.557692  0.423077    0.619718  1.111219
# 159              0.317308            0.557692  0.230769    0.727273  1.304075
# 170              0.394231            0.557692  0.240385    0.609756  1.093356
# ...                   ...                 ...       ...         ...       ...
# 19610            0.240385            0.557692  0.134615    0.560000  1.004138
# 19669            0.163462            0.557692  0.105769    0.647059  1.160243
# 19710            0.125000            0.557692  0.105769    0.846154  1.517241
# 19834            0.182692            0.557692  0.105769    0.578947  1.038113
# 19959            0.201923            0.557692  0.144231    0.714286  1.280788
#
#        leverage  conviction
# 103    0.017751    1.061538
# 121    0.037722    1.326923
# 145    0.042345    1.163105
# 159    0.053809    1.621795
# 170    0.020525    1.133413
# ...         ...         ...
# 19610  0.000555    1.005245
# 19669  0.014608    1.253205
# 19710  0.036058    2.875000
# 19834  0.003883    1.050481
# 19959  0.031620    1.548077
#
# [324 rows x 9 columns]

# %%
won_rules = won_rules[(won_rules['antecedents'].str.len() > 1)] #Here won_rules['antecedents'] is a frozenset

# %%
won_rules
# Out:
#                                              antecedents consequents  \
# 372                                  (A Zampa, AT Carey)       (won)
# 476                                (GJ Maxwell, A Zampa)       (won)
# 539                                  (A Zampa, MA Starc)       (won)
# 649                             (PSP Handscomb, A Zampa)       (won)
# 679                                (UT Khawaja, A Zampa)       (won)
# ...                                                  ...         ...
# 19610  (AJ Finch, MA Starc, PJ Cummins, DA Warner, SP...       (won)
# 19669  (AJ Finch, MA Starc, PJ Cummins, SPD Smith, GJ...       (won)
# 19710  (JR Hazlewood, AJ Finch, MR Marsh, MA Starc, S...       (won)
# 19834  (GJ Bailey, MS Wade, MR Marsh, DA Warner, SPD ...       (won)
# 19959  (MA Starc, PJ Cummins, DA Warner, SPD Smith, G...       (won)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 372              0.259615            0.557692  0.153846    0.592593  1.062580
# 476              0.288462            0.557692  0.173077    0.600000  1.075862
# 539              0.298077            0.557692  0.173077    0.580645  1.041157
# 649              0.153846            0.557692  0.105769    0.687500  1.232759
# 679              0.250000            0.557692  0.182692    0.730769  1.310345
# ...                   ...                 ...       ...         ...       ...
# 19610            0.240385            0.557692  0.134615    0.560000  1.004138
# 19669            0.163462            0.557692  0.105769    0.647059  1.160243
# 19710            0.125000            0.557692  0.105769    0.846154  1.517241
# 19834            0.182692            0.557692  0.105769    0.578947  1.038113
# 19959            0.201923            0.557692  0.144231    0.714286  1.280788
#
#        leverage  conviction
# 372    0.009061    1.085664
# 476    0.012204    1.105769
# 539    0.006842    1.054734
# 649    0.019970    1.415385
# 679    0.043269    1.642857
# ...         ...         ...
# 19610  0.000555    1.005245
# 19669  0.014608    1.253205
# 19710  0.036058    2.875000
# 19834  0.003883    1.050481
# 19959  0.031620    1.548077
#
# [313 rows x 9 columns]

# %%
won_rules.to_csv('aus_won_rules.csv')
