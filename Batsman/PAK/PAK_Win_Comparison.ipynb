# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data file
data = pd.read_csv('pak_data1.csv')

# %%
data.head()
# Out:
#   Result               p1  p1-s             p2  p2-s            p3  p3-s  \
# 0   lost  Mohammad Hafeez     0  Ahmed Shehzad    15   Younis Khan     9
# 1   lost  Mohammad Hafeez    86  Ahmed Shehzad    55   Younis Khan    11
# 2   lost    Ahmed Shehzad    47    Younis Khan    36  Haris Sohail     6
# 3   lost    Nasir Jamshed     0  Ahmed Shehzad     1   Younis Khan     0
# 4    won    Nasir Jamshed     1  Ahmed Shehzad     0  Haris Sohail    27
#
#               p4  p4-s              p5  ...              p7 p7-s  \
# 0  Misbah-ul-Haq    58    Haris Sohail  ...  Sarfaraz Ahmed    5
# 1  Misbah-ul-Haq    45   Shahid Afridi  ...    Haris Sohail    6
# 2  Misbah-ul-Haq    76  Sohaib Maqsood  ...   Shahid Afridi   22
# 3   Haris Sohail     0   Misbah-ul-Haq  ...      Umar Akmal   59
# 4  Misbah-ul-Haq    73      Umar Akmal  ...  Sohaib Maqsood   21
#
#                p8 p8-s              p9 p9-s          p10 p10-s  \
# 0   Shahid Afridi   67  Bilawal Bhatti    0   Ehsan Adil     6
# 1  Sarfaraz Ahmed   13  Bilawal Bhatti    9   Ehsan Adil     1
# 2      Wahab Riaz    4      Yasir Shah   13  Sohail Khan     7
# 3   Shahid Afridi   28      Wahab Riaz    3  Sohail Khan     1
# 4      Wahab Riaz   54     Sohail Khan    6    Rahat Ali     0
#
#               p11 p11-s
# 0  Mohammad Irfan     1
# 1  Mohammad Irfan     0
# 2  Mohammad Irfan     1
# 3  Mohammad Irfan     2
# 4  Mohammad Irfan     0
#
# [5 rows x 23 columns]

# %%
data = data[data.Result == 'won']

# %%
data
# Out:
#    Result               p1  p1-s              p2  p2-s               p3  p3-s  \
# 4     won    Nasir Jamshed     1   Ahmed Shehzad     0     Haris Sohail    27
# 5     won   Sarfaraz Ahmed    49   Ahmed Shehzad    18      Younis Khan    37
# 6     won    Ahmed Shehzad    63  Sarfaraz Ahmed   101     Haris Sohail     3
# 11    won  Mohammad Hafeez    86       Azhar Ali    79     Shoaib Malik   112
# 12    won        Azhar Ali   102  Sarfaraz Ahmed    22  Mohammad Hafeez    15
# 13    won        Azhar Ali    21   Ahmed Shehzad    29  Mohammad Hafeez   103
# 15    won    Ahmed Shehzad    44       Azhar Ali    49  Mohammad Hafeez    54
# 16    won        Azhar Ali    33   Ahmed Shehzad    95  Mohammad Hafeez    70
# 18    won        Azhar Ali    11   Ahmed Shehzad    12  Mohammad Hafeez    10
# 20    won    Ahmed Shehzad    32      Bilal Asif    38  Mohammad Hafeez    13
# 21    won        Azhar Ali     8      Bilal Asif     2  Mohammad Hafeez   102
# 27    won        Azhar Ali     1   Sharjeel Khan   152  Mohammad Hafeez    37
# 32    won        Azhar Ali    33   Sharjeel Khan    10       Babar Azam    31
# 33    won        Azhar Ali     0   Sharjeel Khan    54       Babar Azam   120
# 34    won        Azhar Ali     9   Sharjeel Khan    24       Babar Azam   123
# 35    won        Azhar Ali   101   Sharjeel Khan    38       Babar Azam   117
# 37    won  Mohammad Hafeez    72   Sharjeel Khan    29       Babar Azam    34
# 42    won    Ahmed Shehzad     5    Kamran Akmal    21       Babar Azam   125
# 43    won     Kamran Akmal     0   Ahmed Shehzad     3       Babar Azam    16
# 45    won        Azhar Ali     9    Fakhar Zaman    31       Babar Azam    31
# 46    won        Azhar Ali    34    Fakhar Zaman    50       Babar Azam    10
# 47    won        Azhar Ali    76    Fakhar Zaman    57       Babar Azam    38
# 48    won        Azhar Ali    59    Fakhar Zaman   114       Babar Azam    46
# 49    won     Fakhar Zaman    43   Ahmed Shehzad     0       Babar Azam   103
# 50    won     Fakhar Zaman    11   Ahmed Shehzad     8       Babar Azam   101
# 51    won      Imam-ul-Haq   100    Fakhar Zaman    29       Babar Azam    30
# 52    won      Imam-ul-Haq     2    Fakhar Zaman    17       Babar Azam    69
# 53    won      Imam-ul-Haq    45    Fakhar Zaman    48    Faheem Ashraf     5
# 59    won      Imam-ul-Haq   128    Fakhar Zaman    60       Babar Azam    30
# 60    won      Imam-ul-Haq    44    Fakhar Zaman   117       Babar Azam    29
# 61    won      Imam-ul-Haq     0    Fakhar Zaman    43       Babar Azam    19
# 62    won      Imam-ul-Haq   113    Fakhar Zaman   210         Asif Ali    50
# 63    won      Imam-ul-Haq   110    Fakhar Zaman    85       Babar Azam   116
# 65    won     Fakhar Zaman     0     Imam-ul-Haq    80       Babar Azam    66
# 69    won      Imam-ul-Haq    16    Fakhar Zaman    88       Babar Azam    46
# 70    won      Imam-ul-Haq    86    Fakhar Zaman    25       Babar Azam    49
# 73    won      Imam-ul-Haq    71    Fakhar Zaman    44       Babar Azam    41
# 85    won      Imam-ul-Haq    44    Fakhar Zaman    36       Babar Azam    63
# 88    won      Imam-ul-Haq    44    Fakhar Zaman    44       Babar Azam    69
# 89    won      Imam-ul-Haq    19    Fakhar Zaman     9       Babar Azam   101
# 90    won     Fakhar Zaman     0     Imam-ul-Haq    36       Babar Azam    45
# 91    won     Fakhar Zaman    13     Imam-ul-Haq   100       Babar Azam    96
# 92    won     Fakhar Zaman    54     Imam-ul-Haq    31       Babar Azam   115
# 93    won     Fakhar Zaman    76        Abid Ali    74       Babar Azam    31
#
#                  p4  p4-s               p5  ...               p7 p7-s  \
# 4     Misbah-ul-Haq    73       Umar Akmal  ...   Sohaib Maqsood   21
# 5     Misbah-ul-Haq    56   Sohaib Maqsood  ...    Shahid Afridi   22
# 6     Misbah-ul-Haq    39       Umar Akmal  ...    Shahid Afridi    0
# 11     Haris Sohail    89       Yasir Shah  ...        Anwar Ali    0
# 12      Asad Shafiq    39     Haris Sohail  ...        Anwar Ali    0
# 13       Babar Azam    25     Shoaib Malik  ...        Anwar Ali    0
# 15   Sarfaraz Ahmed    77     Shoaib Malik  ...        Anwar Ali    0
# 16   Sarfaraz Ahmed    17     Shoaib Malik  ...        Anwar Ali    0
# 18   Sarfaraz Ahmed    44     Shoaib Malik  ...       Imad Wasim   61
# 20      Asad Shafiq    38     Shoaib Malik  ...      Aamer Yamin    0
# 21      Younis Khan     9     Shoaib Malik  ...   Sarfaraz Ahmed    0
# 27       Babar Azam    29   Sarfaraz Ahmed  ...   Mohammad Nawaz   53
# 32     Shoaib Malik    77   Sarfaraz Ahmed  ...   Mohammad Nawaz    2
# 33     Shoaib Malik     6   Sarfaraz Ahmed  ...       Imad Wasim   24
# 34     Shoaib Malik    90   Sarfaraz Ahmed  ...  Mohammad Rizwan    6
# 35     Shoaib Malik     5   Sarfaraz Ahmed  ...       Imad Wasim    4
# 37      Asad Shafiq    13     Shoaib Malik  ...  Mohammad Rizwan    0
# 42  Mohammad Hafeez    32     Shoaib Malik  ...       Imad Wasim   43
# 43  Mohammad Hafeez    81     Shoaib Malik  ...       Imad Wasim    0
# 45  Mohammad Hafeez    26     Shoaib Malik  ...       Imad Wasim    0
# 46  Mohammad Hafeez     1     Shoaib Malik  ...       Imad Wasim    4
# 47  Mohammad Hafeez    31     Shoaib Malik  ...       Imad Wasim    0
# 48     Shoaib Malik    12  Mohammad Hafeez  ...   Sarfaraz Ahmed    0
# 49  Mohammad Hafeez    32     Shoaib Malik  ...       Imad Wasim   10
# 50  Mohammad Hafeez     8     Shoaib Malik  ...       Imad Wasim   10
# 51  Mohammad Hafeez    34     Shoaib Malik  ...    Faheem Ashraf    0
# 52  Mohammad Hafeez     9     Shoaib Malik  ...       Imad Wasim    0
# 53       Babar Azam     0  Mohammad Hafeez  ...   Sarfaraz Ahmed    0
# 59     Shoaib Malik    22         Asif Ali  ...   Sarfaraz Ahmed   13
# 60     Shoaib Malik     0   Sarfaraz Ahmed  ...    Faheem Ashraf    0
# 61     Shoaib Malik     0         Asif Ali  ...    Faheem Ashraf    0
# 62       Babar Azam     0     Shoaib Malik  ...    Faheem Ashraf    0
# 63     Shoaib Malik    18         Asif Ali  ...      Shadab Khan    0
# 65     Haris Sohail    13     Shoaib Malik  ...         Asif Ali    7
# 69  Mohammad Hafeez    27     Shoaib Malik  ...      Shadab Khan    2
# 70  Mohammad Hafeez    71     Shoaib Malik  ...      Shadab Khan   18
# 73  Mohammad Rizwan     4  Mohammad Hafeez  ...       Imad Wasim    0
# 85  Mohammad Hafeez    84   Sarfaraz Ahmed  ...     Shoaib Malik    8
# 88  Mohammad Hafeez    20     Haris Sohail  ...       Wahab Riaz    4
# 89  Mohammad Hafeez    32     Haris Sohail  ...       Imad Wasim    0
# 90  Mohammad Hafeez    19     Haris Sohail  ...       Imad Wasim   49
# 91  Mohammad Hafeez    27     Haris Sohail  ...   Sarfaraz Ahmed    3
# 92     Haris Sohail    40   Sarfaraz Ahmed  ...       Imad Wasim   12
# 93   Sarfaraz Ahmed    23     Haris Sohail  ...       Wahab Riaz    1
#
#                 p8 p8-s               p9 p9-s             p10 p10-s  \
# 4       Wahab Riaz   54      Sohail Khan    6       Rahat Ali     0
# 5       Wahab Riaz    0      Sohail Khan    3       Rahat Ali     1
# 6        Rahat Ali    0       Wahab Riaz    0  Sohaib Maqsood     0
# 11     Hammad Azam    0       Wahab Riaz    0   Mohammad Sami     0
# 12     Hammad Azam    0       Yasir Shah    0   Mohammad Sami     0
# 13      Yasir Shah    0   Sarfaraz Ahmed    0  Mohammad Irfan     0
# 15      Imad Wasim    0       Yasir Shah    0  Mohammad Irfan     0
# 16      Imad Wasim    0       Yasir Shah    0  Mohammad Irfan     0
# 18     Aamer Yamin    1       Yasir Shah    0  Mohammad Irfan     0
# 20      Imad Wasim    0  Mohammad Rizwan    0  Mohammad Irfan     0
# 21      Yasir Shah    0        Anwar Ali    0  Mohammad Irfan     0
# 27      Imad Wasim    0         Umar Gul    0   Mohammad Amir     0
# 32      Imad Wasim   16         Umar Gul    0   Mohammad Amir     0
# 33  Mohammad Nawaz   19       Wahab Riaz    0   Mohammad Amir     3
# 34  Mohammad Nawaz    0       Wahab Riaz    0   Mohammad Amir     0
# 35  Mohammad Nawaz    4        Hasan Ali    0     Sohail Khan     0
# 37      Imad Wasim    0    Mohammad Amir    0       Hasan Ali     0
# 42     Shadab Khan    0    Mohammad Amir    0       Hasan Ali     0
# 43     Shadab Khan    0    Mohammad Amir    0       Hasan Ali     0
# 45   Mohammad Amir    0      Shadab Khan    0       Hasan Ali     0
# 46   Faheem Ashraf   15    Mohammad Amir   28       Hasan Ali     0
# 47    Rumman Raees    0      Shadab Khan    0       Hasan Ali     0
# 48   Mohammad Amir    0      Shadab Khan    0       Hasan Ali     0
# 49       Hasan Ali   11     Rumman Raees    0     Shadab Khan     0
# 50     Shadab Khan   52        Hasan Ali    7    Rumman Raees     0
# 51     Shadab Khan    0        Hasan Ali    0    Rumman Raees     0
# 52     Shadab Khan    0        Hasan Ali    0  Usman Shinwari     0
# 53      Imad Wasim    0      Shadab Khan    0       Hasan Ali     0
# 59       Hasan Ali    0      Shadab Khan    2   Mohammad Amir     0
# 60     Shadab Khan    0        Hasan Ali    0   Mohammad Amir     0
# 61     Shadab Khan    0       Yasir Shah    0     Junaid Khan     0
# 62     Shadab Khan    0       Yasir Shah    0     Junaid Khan     0
# 63  Mohammad Nawaz    0    Mohammad Amir    0       Hasan Ali     0
# 65  Mohammad Nawaz   10        Hasan Ali    6  Usman Shinwari     0
# 69   Faheem Ashraf    0       Imad Wasim    0       Hasan Ali     0
# 70      Imad Wasim    0    Faheem Ashraf    0       Hasan Ali     0
# 73     Shadab Khan    0    Mohammad Amir    0  Usman Shinwari     0
# 85      Wahab Riaz    4        Hasan Ali   10     Shadab Khan    10
# 88  Sarfaraz Ahmed    2      Shadab Khan    1   Mohammad Amir     0
# 89      Wahab Riaz    0      Shadab Khan    0   Mohammad Amir     0
# 90     Shadab Khan   11       Wahab Riaz   15   Mohammad Amir     0
# 91      Wahab Riaz    2      Shadab Khan    1   Mohammad Amir     8
# 92      Wahab Riaz    2      Shadab Khan    0   Mohammad Amir     0
# 93  Mohammad Nawaz    0      Shadab Khan    0   Mohammad Amir     0
#
#                     p11 p11-s
# 4        Mohammad Irfan     0
# 5        Mohammad Irfan     1
# 6           Sohail Khan     0
# 11          Asad Shafiq     0
# 12           Wahab Riaz     0
# 13            Rahat Ali     0
# 15            Rahat Ali     0
# 16            Rahat Ali     0
# 18           Wahab Riaz     0
# 20           Wahab Riaz     0
# 21           Wahab Riaz     0
# 27            Hasan Ali     0
# 32            Hasan Ali     0
# 33            Hasan Ali     2
# 34            Hasan Ali     0
# 35           Wahab Riaz     0
# 37          Junaid Khan     0
# 42          Junaid Khan     0
# 43          Junaid Khan     0
# 45          Junaid Khan     0
# 46          Junaid Khan     0
# 47          Junaid Khan     0
# 48          Junaid Khan     0
# 49          Junaid Khan     0
# 50          Junaid Khan     0
# 51          Junaid Khan     0
# 52          Junaid Khan     0
# 53       Usman Shinwari     0
# 59       Usman Shinwari     0
# 60       Usman Shinwari     0
# 61       Usman Shinwari     0
# 62       Usman Shinwari     0
# 63          Junaid Khan     0
# 65  Shaheen Shah Afridi     0
# 69          Shah Afridi     0
# 70       Usman Shinwari     0
# 73  Shaheen Shah Afridi     0
# 85        Mohammad Amir     0
# 88  Shaheen Shah Afridi     0
# 89  Shaheen Shah Afridi     0
# 90  Shaheen Shah Afridi     0
# 91  Shaheen Shah Afridi     0
# 92       Usman Shinwari     0
# 93       Usman Shinwari     0
#
# [44 rows x 23 columns]

# %%
del data['Result']

# %%
data = data.reset_index(drop=True)

# %%
x = set()
print(x)
# Out:
# set()

# %%
players = ['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11']

# %%
for i in players:
    for j in range(len(data[i].unique())):
        x.add(data[i].unique()[j])

# %%
print(x)
# Out:
# {'Umar Gul', 'Shaheen Shah Afridi', 'Rumman Raees', 'Mohammad Hafeez', 'Mohammad Nawaz', 'Anwar Ali', 'Rahat Ali', 'Mohammad Sami', 'Mohammad Irfan', 'Shahid Afridi', 'Misbah-ul-Haq', 'Sohaib Maqsood', 'Abid Ali', 'Sarfaraz Ahmed', 'Sharjeel Khan', 'Aamer Yamin', 'Mohammad Amir', 'Hasan Ali', 'Younis Khan', 'Imad Wasim', 'Azhar Ali', 'Haris Sohail', 'Mohammad Rizwan', 'Asif Ali', 'Iftikhar Ahmed', 'Umar Akmal', 'Ehsan Adil', 'Junaid Khan', 'Kamran Akmal', 'Shah Afridi', 'Babar Azam', 'Shadab Khan', 'Ahmed Shehzad', 'Usman Shinwari', 'Sohail Khan', 'Yasir Shah', 'Fakhar Zaman', 'Hammad Azam', 'Bilal Asif', 'Asad Shafiq', 'Wahab Riaz', 'Nasir Jamshed', 'Shoaib Malik', 'Imam-ul-Haq', 'Faheem Ashraf'}

# %%
len(x)
# Out:
# 45

# %%
import itertools 
# def findsubsets(s, n): 
def findsubsets(s, n): 
    return [set(i) for i in itertools.combinations(s, n)]

# %%
sub2 = findsubsets(x,2)

# %%
len(sub2)
# Out:
# 990

# %%
for t in sub2:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        sub2.remove(t)

# %%
len(sub2)
# Out:
# 662

# %%
#load data file which includes both won lost data
data_all = pd.read_csv('pak.csv')

# %%
column_names = ["player-1", "player-2", "avg"]

result_2grams = pd.DataFrame(columns = column_names)

# %%
player_scores = ['p1-s','p2-s','p3-s','p4-s','p5-s','p6-s','p7-s','p8-s','p9-s','p10-s','p11-s']

# %%
for t in sub2:
    new_list = list(t)
    df = data_all[np.equal.outer(data_all.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':avg}, ignore_index=True)

# %%
unique_list = list(x)
print(unique_list)
# Out:
# ['Umar Gul', 'Shaheen Shah Afridi', 'Rumman Raees', 'Mohammad Hafeez', 'Mohammad Nawaz', 'Anwar Ali', 'Rahat Ali', 'Mohammad Sami', 'Mohammad Irfan', 'Shahid Afridi', 'Misbah-ul-Haq', 'Sohaib Maqsood', 'Abid Ali', 'Sarfaraz Ahmed', 'Sharjeel Khan', 'Aamer Yamin', 'Mohammad Amir', 'Hasan Ali', 'Younis Khan', 'Imad Wasim', 'Azhar Ali', 'Haris Sohail', 'Mohammad Rizwan', 'Asif Ali', 'Iftikhar Ahmed', 'Umar Akmal', 'Ehsan Adil', 'Junaid Khan', 'Kamran Akmal', 'Shah Afridi', 'Babar Azam', 'Shadab Khan', 'Ahmed Shehzad', 'Usman Shinwari', 'Sohail Khan', 'Yasir Shah', 'Fakhar Zaman', 'Hammad Azam', 'Bilal Asif', 'Asad Shafiq', 'Wahab Riaz', 'Nasir Jamshed', 'Shoaib Malik', 'Imam-ul-Haq', 'Faheem Ashraf']

# %%
column_names = ["player_name", "sum", "avg"]

result = pd.DataFrame(columns = column_names)

# %%
dictionary = dict()

for indx, name in enumerate(unique_list):
    count = 0
    sum = 0
    for index, row in data_all.iterrows():
        for ind, p in enumerate(players):
                if(data_all.iloc[index][p] == name ):
#                     print(name)
                    sum = sum + data_all.iloc[index][player_scores[ind]] 
                    count += 1
    avg = round((sum/count),2)
    print(name," : sum=",sum," , count=",count," , average=",round(avg,2))    
    dictionary[name] = avg
    result = result.append({'player_name':name, 'sum':sum, 'avg':avg}, ignore_index=True)
    
print(dictionary)
# Out:
# Umar Gul  : sum= 6  , count= 5  , average= 1.2
# Shaheen Shah Afridi  : sum= 42  , count= 16  , average= 2.62
# Rumman Raees  : sum= 27  , count= 9  , average= 3.0
# Mohammad Hafeez  : sum= 2059  , count= 63  , average= 32.68
# Mohammad Nawaz  : sum= 199  , count= 15  , average= 13.27
# Anwar Ali  : sum= 110  , count= 12  , average= 9.17
# Rahat Ali  : sum= 8  , count= 12  , average= 0.67
# Mohammad Sami  : sum= 0  , count= 2  , average= 0.0
# Mohammad Irfan  : sum= 9  , count= 21  , average= 0.43
# Shahid Afridi  : sum= 183  , count= 8  , average= 22.88
# Misbah-ul-Haq  : sum= 388  , count= 8  , average= 48.5
# Sohaib Maqsood  : sum= 118  , count= 7  , average= 16.86
# Abid Ali  : sum= 191  , count= 4  , average= 47.75
# Sarfaraz Ahmed  : sum= 1821  , count= 78  , average= 23.35
# Sharjeel Khan  : sum= 618  , count= 14  , average= 44.14
# Aamer Yamin  : sum= 95  , count= 4  , average= 23.75
# Mohammad Amir  : sum= 196  , count= 44  , average= 4.45
# Hasan Ali  : sum= 278  , count= 50  , average= 5.56
# Younis Khan  : sum= 102  , count= 6  , average= 17.0
# Imad Wasim  : sum= 952  , count= 52  , average= 18.31
# Azhar Ali  : sum= 1347  , count= 38  , average= 35.45
# Haris Sohail  : sum= 1160  , count= 29  , average= 40.0
# Mohammad Rizwan  : sum= 705  , count= 32  , average= 22.03
# Asif Ali  : sum= 352  , count= 15  , average= 23.47
# Iftikhar Ahmed  : sum= 68  , count= 4  , average= 17.0
# Umar Akmal  : sum= 443  , count= 18  , average= 24.61
# Ehsan Adil  : sum= 22  , count= 4  , average= 5.5
# Junaid Khan  : sum= 12  , count= 27  , average= 0.44
# Kamran Akmal  : sum= 68  , count= 3  , average= 22.67
# Shah Afridi  : sum= 0  , count= 1  , average= 0.0
# Babar Azam  : sum= 3174  , count= 70  , average= 45.34
# Shadab Khan  : sum= 337  , count= 41  , average= 8.22
# Ahmed Shehzad  : sum= 597  , count= 24  , average= 24.88
# Usman Shinwari  : sum= 6  , count= 16  , average= 0.38
# Sohail Khan  : sum= 21  , count= 7  , average= 3.0
# Yasir Shah  : sum= 127  , count= 23  , average= 5.52
# Fakhar Zaman  : sum= 1866  , count= 43  , average= 43.4
# Hammad Azam  : sum= 0  , count= 2  , average= 0.0
# Bilal Asif  : sum= 40  , count= 3  , average= 13.33
# Asad Shafiq  : sum= 96  , count= 6  , average= 16.0
# Wahab Riaz  : sum= 337  , count= 40  , average= 8.43
# Nasir Jamshed  : sum= 1  , count= 2  , average= 0.5
# Shoaib Malik  : sum= 2014  , count= 68  , average= 29.62
# Imam-ul-Haq  : sum= 1631  , count= 35  , average= 46.6
# Faheem Ashraf  : sum= 157  , count= 20  , average= 7.85
# {'Umar Gul': 1.2, 'Shaheen Shah Afridi': 2.62, 'Rumman Raees': 3.0, 'Mohammad Hafeez': 32.68, 'Mohammad Nawaz': 13.27, 'Anwar Ali': 9.17, 'Rahat Ali': 0.67, 'Mohammad Sami': 0.0, 'Mohammad Irfan': 0.43, 'Shahid Afridi': 22.88, 'Misbah-ul-Haq': 48.5, 'Sohaib Maqsood': 16.86, 'Abid Ali': 47.75, 'Sarfaraz Ahmed': 23.35, 'Sharjeel Khan': 44.14, 'Aamer Yamin': 23.75, 'Mohammad Amir': 4.45, 'Hasan Ali': 5.56, 'Younis Khan': 17.0, 'Imad Wasim': 18.31, 'Azhar Ali': 35.45, 'Haris Sohail': 40.0, 'Mohammad Rizwan': 22.03, 'Asif Ali': 23.47, 'Iftikhar Ahmed': 17.0, 'Umar Akmal': 24.61, 'Ehsan Adil': 5.5, 'Junaid Khan': 0.44, 'Kamran Akmal': 22.67, 'Shah Afridi': 0.0, 'Babar Azam': 45.34, 'Shadab Khan': 8.22, 'Ahmed Shehzad': 24.88, 'Usman Shinwari': 0.38, 'Sohail Khan': 3.0, 'Yasir Shah': 5.52, 'Fakhar Zaman': 43.4, 'Hammad Azam': 0.0, 'Bilal Asif': 13.33, 'Asad Shafiq': 16.0, 'Wahab Riaz': 8.43, 'Nasir Jamshed': 0.5, 'Shoaib Malik': 29.62, 'Imam-ul-Haq': 46.6, 'Faheem Ashraf': 7.85}

# %%
result_2grams.head()
# Out:
#        player-1         player-2        avg
# 0  Rumman Raees         Umar Gul   0.000000
# 1      Umar Gul  Mohammad Hafeez  17.333333
# 2      Umar Gul   Mohammad Nawaz  22.750000
# 3      Umar Gul        Rahat Ali   0.000000
# 4      Umar Gul   Mohammad Irfan   6.000000

# %%
result_2grams.shape
# Out:
# (662, 3)

# %%
result_2grams = result_2grams[result_2grams.avg != 0.0]

# %%
result_2grams.shape
# Out:
# (484, 3)

# %%
result_2grams = result_2grams.reset_index(drop=True)

# %%
new_column_names = ["player-1", "player-2", "combined_avg","sum_of_individual"]

afg_beautiful2grams = pd.DataFrame(columns = new_column_names)

# %%
for index, row in result_2grams.iterrows():
    player1 = result_2grams.iloc[index]['player-1']
    player2 = result_2grams.iloc[index]['player-2']
    combined = result_2grams.iloc[index]['avg']
    individual_avg_sum = dictionary.get(player1)+dictionary.get(player2)
    if(combined > individual_avg_sum):
        afg_beautiful2grams = afg_beautiful2grams.append({'player-1':player1, 'player-2':player2, 'combined_avg': combined, 'sum_of_individual':individual_avg_sum}, ignore_index=True)

# %%
afg_beautiful2grams.head()
# Out:
#    player-1        player-2  combined_avg  sum_of_individual
# 0  Umar Gul  Mohammad Nawaz         22.75              14.47
# 1  Umar Gul  Mohammad Irfan          6.00               1.63
# 2  Umar Gul  Sarfaraz Ahmed         41.25              24.55
# 3  Umar Gul   Sharjeel Khan         50.00              45.34
# 4  Umar Gul      Imad Wasim         24.00              19.51

# %%
afg_beautiful2grams.shape
# Out:
# (242, 4)

# %%
afg_beautiful2grams.to_csv('pak2grams_won.csv')
