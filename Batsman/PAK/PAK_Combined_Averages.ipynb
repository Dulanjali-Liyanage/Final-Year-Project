# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data file
data = pd.read_csv('pak.csv')

# %%
data.head()
# Out:
#                 p1  p1-s             p2  p2-s            p3  p3-s  \
# 0  Mohammad Hafeez     0  Ahmed Shehzad    15   Younis Khan     9
# 1  Mohammad Hafeez    86  Ahmed Shehzad    55   Younis Khan    11
# 2    Ahmed Shehzad    47    Younis Khan    36  Haris Sohail     6
# 3    Nasir Jamshed     0  Ahmed Shehzad     1   Younis Khan     0
# 4    Nasir Jamshed     1  Ahmed Shehzad     0  Haris Sohail    27
#
#               p4  p4-s              p5  p5-s  ...              p7  p7-s  \
# 0  Misbah-ul-Haq    58    Haris Sohail    23  ...  Sarfaraz Ahmed     5
# 1  Misbah-ul-Haq    45   Shahid Afridi    11  ...    Haris Sohail     6
# 2  Misbah-ul-Haq    76  Sohaib Maqsood     0  ...   Shahid Afridi    22
# 3   Haris Sohail     0   Misbah-ul-Haq     7  ...      Umar Akmal    59
# 4  Misbah-ul-Haq    73      Umar Akmal    33  ...  Sohaib Maqsood    21
#
#                p8  p8-s              p9  p9-s          p10  p10-s  \
# 0   Shahid Afridi    67  Bilawal Bhatti     0   Ehsan Adil      6
# 1  Sarfaraz Ahmed    13  Bilawal Bhatti     9   Ehsan Adil      1
# 2      Wahab Riaz     4      Yasir Shah    13  Sohail Khan      7
# 3   Shahid Afridi    28      Wahab Riaz     3  Sohail Khan      1
# 4      Wahab Riaz    54     Sohail Khan     6    Rahat Ali      0
#
#               p11  p11-s
# 0  Mohammad Irfan      1
# 1  Mohammad Irfan      0
# 2  Mohammad Irfan      1
# 3  Mohammad Irfan      2
# 4  Mohammad Irfan      0
#
# [5 rows x 22 columns]

# %%
x = set()
print(x)
# Out:
# set()

# %%
players = ['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11']

# %%
for i in players:
    for j in range(len(data[i].unique())):
        x.add(data[i].unique()[j])

# %%
print(x)
# Out:
# {'Iftikhar Ahmed', 'Shoaib Malik', 'Yasir Shah', 'Sarfaraz Ahmed', 'Umar Amin', 'Shadab Khan', 'Saad Ali', 'Bilal Asif', 'Aamer Yamin', 'Umar Gul', 'Umar Akmal', 'Zafar Gohar', 'Mohammad Sami', 'Wahab Riaz', 'Rahat Ali', 'Imam-ul-Haq', 'Haris Sohail', 'Kamran Akmal', 'Misbah-ul-Haq', 'Ehsan Adil', 'Imad Wasim', 'Hussain Talat', 'Junaid Khan', 'Rumman Raees', 'Hasan Ali', 'Mohammad Abbas', 'Abid Ali', 'Mohammad Amir', 'Mohammad Hasnain', 'Fakhar Zaman', 'Shan Masood', 'Faheem Ashraf', 'Sohail Khan', 'Asad Shafiq', 'Usman Shinwari', 'Younis Khan', 'Babar Azam', 'Mohammad Hafeez', 'Nasir Jamshed', 'Fawad Alam', 'Mohammad Nawaz', 'Sohaib Maqsood', 'Mohammad Irfan', 'Shahid Afridi', 'Saad Nasim', 'Sami Aslam', 'Sharjeel Khan', 'Anwar Ali', 'Asif Ali', 'Shah Afridi', 'Azhar Ali', 'Zulfiqar Babar', 'Ahmed Shehzad', 'Saeed Ajmal', 'Shaheen Shah Afridi', 'Hammad Azam', 'Mohammad Rizwan', 'Bilawal Bhatti'}

# %%
print(len(x))
# Out:
# 58

# %%
player_scores = ['p1-s','p2-s','p3-s','p4-s','p5-s','p6-s','p7-s','p8-s','p9-s','p10-s','p11-s']

# %%
import itertools 
# def findsubsets(s, n): 
def findsubsets(s, n): 
    return [set(i) for i in itertools.combinations(s, n)]

# %%
#2 grams

# %%
sub2 = findsubsets(x,2)

# %%
column_names = ["player-1", "player-2", "avg"]

result_2grams = pd.DataFrame(columns = column_names)

# %%
for t in sub2:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':avg}, ignore_index=True)

# %%
result_2grams.head(25)
# Out:
#           player-1        player-2    avg
# 0   Iftikhar Ahmed    Shoaib Malik  18.50
# 1   Iftikhar Ahmed      Yasir Shah  21.00
# 2   Iftikhar Ahmed  Sarfaraz Ahmed  47.25
# 3   Iftikhar Ahmed       Umar Amin   0.00
# 4   Iftikhar Ahmed     Shadab Khan  30.00
# 5   Iftikhar Ahmed        Saad Ali   0.00
# 6   Iftikhar Ahmed      Bilal Asif   0.00
# 7   Iftikhar Ahmed     Aamer Yamin   0.00
# 8   Iftikhar Ahmed        Umar Gul   0.00
# 9   Iftikhar Ahmed      Umar Akmal   0.00
# 10  Iftikhar Ahmed     Zafar Gohar  18.00
# 11  Iftikhar Ahmed   Mohammad Sami   0.00
# 12  Iftikhar Ahmed      Wahab Riaz  27.75
# 13  Iftikhar Ahmed       Rahat Ali   0.00
# 14  Iftikhar Ahmed     Imam-ul-Haq  63.00
# 15  Iftikhar Ahmed    Haris Sohail  78.00
# 16  Iftikhar Ahmed    Kamran Akmal   0.00
# 17  Iftikhar Ahmed   Misbah-ul-Haq   0.00
# 18  Iftikhar Ahmed      Ehsan Adil   0.00
# 19  Iftikhar Ahmed      Imad Wasim  44.00
# 20  Iftikhar Ahmed   Hussain Talat   0.00
# 21  Iftikhar Ahmed     Junaid Khan   0.00
# 22  Iftikhar Ahmed    Rumman Raees   0.00
# 23  Iftikhar Ahmed       Hasan Ali   0.00
# 24  Iftikhar Ahmed  Mohammad Abbas   0.00

# %%
result_2grams.to_csv('pak2grams.csv')

# %%
#3 grams

# %%
sub3 = findsubsets(x,3)

# %%
print(len(sub3))
# Out:
# 30856

# %%
column_names = ["player-1", "player-2","player-3", "avg"]

result_3grams = pd.DataFrame(columns = column_names)

# %%
for t in sub3:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_3grams = result_3grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[2] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_3grams = result_3grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'avg':avg}, ignore_index=True)

# %%
result_3grams.head(25)
# Out:
#           player-1      player-2        player-3   avg
# 0   Iftikhar Ahmed  Shoaib Malik      Yasir Shah  34.0
# 1   Iftikhar Ahmed  Shoaib Malik  Sarfaraz Ahmed  63.5
# 2   Iftikhar Ahmed  Shoaib Malik       Umar Amin   0.0
# 3   Iftikhar Ahmed  Shoaib Malik     Shadab Khan   0.0
# 4   Iftikhar Ahmed  Shoaib Malik        Saad Ali   0.0
# 5   Iftikhar Ahmed  Shoaib Malik      Bilal Asif   0.0
# 6   Iftikhar Ahmed  Shoaib Malik     Aamer Yamin   0.0
# 7   Iftikhar Ahmed  Shoaib Malik        Umar Gul   0.0
# 8   Iftikhar Ahmed  Shoaib Malik      Umar Akmal   0.0
# 9   Iftikhar Ahmed  Shoaib Malik     Zafar Gohar  34.0
# 10  Iftikhar Ahmed  Shoaib Malik   Mohammad Sami   0.0
# 11  Iftikhar Ahmed  Shoaib Malik      Wahab Riaz  38.5
# 12  Iftikhar Ahmed     Rahat Ali    Shoaib Malik   0.0
# 13  Iftikhar Ahmed  Shoaib Malik     Imam-ul-Haq   0.0
# 14  Iftikhar Ahmed  Shoaib Malik    Haris Sohail   0.0
# 15  Iftikhar Ahmed  Shoaib Malik    Kamran Akmal   0.0
# 16  Iftikhar Ahmed  Shoaib Malik   Misbah-ul-Haq   0.0
# 17  Iftikhar Ahmed  Shoaib Malik      Ehsan Adil   0.0
# 18  Iftikhar Ahmed    Imad Wasim    Shoaib Malik   0.0
# 19  Iftikhar Ahmed  Shoaib Malik   Hussain Talat   0.0
# 20  Iftikhar Ahmed  Shoaib Malik     Junaid Khan   0.0
# 21  Iftikhar Ahmed  Shoaib Malik    Rumman Raees   0.0
# 22  Iftikhar Ahmed     Hasan Ali    Shoaib Malik   0.0
# 23  Iftikhar Ahmed  Shoaib Malik  Mohammad Abbas   0.0
# 24  Iftikhar Ahmed  Shoaib Malik        Abid Ali   0.0

# %%
result_3grams.to_csv('pak3grams.csv')

# %%
#4 grams

# %%
sub4 = findsubsets(x,4)

# %%
print(len(sub4))
# Out:
# 424270

# %%
column_names = ["player-1", "player-2","player-3", "player-4", "avg"]

result_4grams = pd.DataFrame(columns = column_names)

# %%
for t in sub4:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_4grams = result_4grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[2] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[3] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_4grams = result_4grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'avg':avg}, ignore_index=True)

# %%
result_4grams.head(25)
# Out:
#           player-1      player-2      player-3        player-4   avg
# 0   Iftikhar Ahmed  Shoaib Malik    Yasir Shah  Sarfaraz Ahmed  98.0
# 1   Iftikhar Ahmed     Umar Amin  Shoaib Malik      Yasir Shah   0.0
# 2   Iftikhar Ahmed  Shoaib Malik    Yasir Shah     Shadab Khan   0.0
# 3   Iftikhar Ahmed  Shoaib Malik    Yasir Shah        Saad Ali   0.0
# 4   Iftikhar Ahmed  Shoaib Malik    Yasir Shah      Bilal Asif   0.0
# 5   Iftikhar Ahmed  Shoaib Malik    Yasir Shah     Aamer Yamin   0.0
# 6   Iftikhar Ahmed  Shoaib Malik    Yasir Shah        Umar Gul   0.0
# 7   Iftikhar Ahmed  Shoaib Malik    Umar Akmal      Yasir Shah   0.0
# 8   Iftikhar Ahmed  Shoaib Malik    Yasir Shah     Zafar Gohar   0.0
# 9   Iftikhar Ahmed  Shoaib Malik    Yasir Shah   Mohammad Sami   0.0
# 10  Iftikhar Ahmed  Shoaib Malik    Yasir Shah      Wahab Riaz  39.0
# 11  Iftikhar Ahmed     Rahat Ali  Shoaib Malik      Yasir Shah   0.0
# 12  Iftikhar Ahmed  Shoaib Malik    Yasir Shah     Imam-ul-Haq   0.0
# 13  Iftikhar Ahmed  Shoaib Malik    Yasir Shah    Haris Sohail   0.0
# 14  Iftikhar Ahmed  Shoaib Malik    Yasir Shah    Kamran Akmal   0.0
# 15  Iftikhar Ahmed  Shoaib Malik    Yasir Shah   Misbah-ul-Haq   0.0
# 16  Iftikhar Ahmed  Shoaib Malik    Yasir Shah      Ehsan Adil   0.0
# 17  Iftikhar Ahmed    Imad Wasim  Shoaib Malik      Yasir Shah   0.0
# 18  Iftikhar Ahmed  Shoaib Malik    Yasir Shah   Hussain Talat   0.0
# 19  Iftikhar Ahmed  Shoaib Malik    Yasir Shah     Junaid Khan   0.0
# 20  Iftikhar Ahmed  Shoaib Malik    Yasir Shah    Rumman Raees   0.0
# 21  Iftikhar Ahmed     Hasan Ali  Shoaib Malik      Yasir Shah   0.0
# 22  Iftikhar Ahmed  Shoaib Malik    Yasir Shah  Mohammad Abbas   0.0
# 23  Iftikhar Ahmed  Shoaib Malik    Yasir Shah        Abid Ali   0.0
# 24  Iftikhar Ahmed  Shoaib Malik    Yasir Shah   Mohammad Amir   0.0

# %%
result_4grams.to_csv('pak4grams.csv')
