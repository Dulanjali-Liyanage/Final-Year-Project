# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data file
data = pd.read_csv('aus_data1.csv')

# %%
data.head()
# Out:
#   Result         p1  p1-s         p2  p2-s         p3  p3-s         p4  p4-s  \
# 0    won  DA Warner   127   AJ Finch    15  SR Watson    16  SPD Smith    37
# 1    won   AJ Finch    96  DA Warner    24  SR Watson    41  SPD Smith    47
# 2    won   AJ Finch    32   SE Marsh    45  SPD Smith   102   CL White     0
# 3    won   AJ Finch     0  DA Warner    12  SPD Smith    40  GJ Bailey     2
# 4    won  DA Warner    22   AJ Finch   135  SR Watson     0  SPD Smith     5
#
#            p5  ...         p7 p7-s            p8 p8-s          p9 p9-s  \
# 0   GJ Bailey  ...  BJ Haddin   16   JP Faulkner    6    MA Starc    0
# 1  GJ Maxwell  ...  BJ Haddin   13   JP Faulkner    9    MA Starc    0
# 2  GJ Maxwell  ...  BJ Haddin   42  MC Henriques    4    MA Starc    1
# 3  GJ Maxwell  ...  BJ Haddin    9   JP Faulkner   50  MG Johnson    3
# 4   GJ Bailey  ...   MR Marsh   23     BJ Haddin   31  MG Johnson    0
#
#           p10 p10-s           p11 p11-s
# 0  PJ Cummins     0    XJ Doherty     0
# 1  PJ Cummins     0     GS Sandhu     0
# 2  PJ Cummins     0     GS Sandhu     0
# 3    MA Starc     0  JR Hazlewood     0
# 4    MA Starc     0  JR Hazlewood     0
#
# [5 rows x 23 columns]

# %%
data = data[data.Result == 'won']

# %%
data
# Out:
#     Result          p1  p1-s          p2  p2-s             p3  p3-s  \
# 0      won   DA Warner   127    AJ Finch    15      SR Watson    16
# 1      won    AJ Finch    96   DA Warner    24      SR Watson    41
# 2      won    AJ Finch    32    SE Marsh    45      SPD Smith   102
# 3      won    AJ Finch     0   DA Warner    12      SPD Smith    40
# 4      won   DA Warner    22    AJ Finch   135      SR Watson     0
# 6      won   DA Warner   178    AJ Finch     4      SPD Smith    95
# 7      won    AJ Finch    24   DA Warner     9      SPD Smith    72
# 8      won   DA Warner    24    AJ Finch     2      SPD Smith    65
# 9      won    AJ Finch    81   DA Warner    12      SPD Smith   105
# 10     won   DA Warner    45    AJ Finch     0      SPD Smith    56
# 11     won    JA Burns    69   DA Warner    84      SPD Smith    21
# 12     won    JA Burns    44   DA Warner    59      SPD Smith    44
# 13     won    JA Burns    22   DA Warner     1      SPD Smith    70
# 16     won    JA Burns     0    AJ Finch    70      SPD Smith    12
# 17     won    AJ Finch     8   DA Warner     5      SPD Smith   149
# 18     won    AJ Finch    71    SE Marsh    71      SPD Smith    46
# 19     won    SE Marsh    62    AJ Finch    21      SPD Smith    41
# 20     won   DA Warner    93    AJ Finch   107       MR Marsh    33
# 23     won  UT Khawaja    50   DA Warner    98      SPD Smith     2
# 25     won   DA Warner    55    AJ Finch    19     UT Khawaja    27
# 27     won   DA Warner   109    AJ Finch    13     UT Khawaja    59
# 29     won  UT Khawaja    17    AJ Finch    16      SPD Smith    78
# 30     won  UT Khawaja    14    AJ Finch    47      SPD Smith    46
# 31     won   DA Warner     8    AJ Finch    56      SPD Smith    58
# 33     won   DA Warner    10    AJ Finch    30       SE Marsh     1
# 34     won   DA Warner    19    AJ Finch    55     UT Khawaja     0
# 35     won   DA Warner   106     MS Wade     3     UT Khawaja     6
# 36     won  UT Khawaja    82   DA Warner    48      SPD Smith    59
# 42     won   DA Warner    24    AJ Finch     0      SPD Smith   164
# 43     won   DA Warner   119    AJ Finch    19      SPD Smith    72
# 44     won   DA Warner   156    AJ Finch     3      SPD Smith     0
# 45     won   DA Warner     7     TM Head    39      SPD Smith     0
# 47     won   DA Warner    35  UT Khawaja     9      SPD Smith   108
# 48     won  UT Khawaja    30   DA Warner   130      SPD Smith    49
# 49     won   DA Warner   179     TM Head   128      SPD Smith     4
# 56     won    AJ Finch    94   DA Warner   124        TM Head    29
# 61     won   DA Warner    13     TM Head    96       CL White     3
# 69     won    AJ Finch    41     TM Head     8       SE Marsh    22
# 71     won    AT Carey    24    AJ Finch     6     UT Khawaja    59
# 76     won    AJ Finch    93  UT Khawaja   104     GJ Maxwell    47
# 77     won    AJ Finch     0  UT Khawaja    91       SE Marsh     6
# 78     won  UT Khawaja   100    AJ Finch    27  PSP Handscomb    52
# 79     won  UT Khawaja    24    AJ Finch   116       SE Marsh    91
# 80     won  UT Khawaja    88    AJ Finch   153     GJ Maxwell    19
# 81     won  UT Khawaja     0    AJ Finch    90       SE Marsh    14
# 82     won    AJ Finch    39  UT Khawaja    62       SE Marsh     5
# 83     won  UT Khawaja    98    AJ Finch    53       SE Marsh    61
# 84     won    AJ Finch    66   DA Warner    89     UT Khawaja    15
# 85     won   DA Warner     3    AJ Finch     6     UT Khawaja    13
# 87     won    AJ Finch    82   DA Warner   107      SPD Smith    10
# 88     won    AJ Finch    26   DA Warner   153     UT Khawaja    10
# 89     won   DA Warner   166    AJ Finch    53     UT Khawaja    89
# 90     won    AJ Finch   100   DA Warner    53     UT Khawaja    23
# 91     won   DA Warner    16    AJ Finch     8     UT Khawaja    88
# 94     won   DA Warner   128    AJ Finch   110  M Labuschagne     0
# 100    won   DA Warner    67    AJ Finch    60      SPD Smith    14
# 101    won   DA Warner     6    AJ Finch    16     MP Stoinis    43
# 103    won   DA Warner    24    AJ Finch    12     MP Stoinis     4
#
#                 p4  p4-s             p5  ...             p7 p7-s  \
# 0        SPD Smith    37      GJ Bailey  ...      BJ Haddin   16
# 1        SPD Smith    47     GJ Maxwell  ...      BJ Haddin   13
# 2         CL White     0     GJ Maxwell  ...      BJ Haddin   42
# 3        GJ Bailey     2     GJ Maxwell  ...      BJ Haddin    9
# 4        SPD Smith     5      GJ Bailey  ...       MR Marsh   23
# 6       GJ Maxwell    88    JP Faulkner  ...      BJ Haddin   20
# 7        MJ Clarke    68     GJ Maxwell  ...    JP Faulkner    0
# 8        MJ Clarke     8      SR Watson  ...      BJ Haddin    0
# 9       GJ Maxwell    23      SR Watson  ...    JP Faulkner   21
# 10       MJ Clarke    74      SR Watson  ...      BJ Haddin    0
# 11       GJ Bailey     1     GJ Maxwell  ...       MR Marsh   11
# 12       GJ Bailey    23     GJ Maxwell  ...        MS Wade   71
# 13       GJ Bailey    54     GJ Maxwell  ...       MR Marsh   64
# 16       GJ Bailey    41       MR Marsh  ...        MS Wade    0
# 17       GJ Bailey   112     GJ Maxwell  ...    JP Faulkner    1
# 18       GJ Bailey    76     GJ Maxwell  ...  KW Richardson    0
# 19       GJ Bailey    23     GJ Maxwell  ...        MS Wade    6
# 20       SPD Smith    51     GJ Maxwell  ...    JP Faulkner    0
# 23       GJ Bailey     0     GJ Maxwell  ...        MS Wade    2
# 25       SPD Smith     6     GJ Maxwell  ...        MS Wade    0
# 27       SPD Smith    52      GJ Bailey  ...        MS Wade   24
# 29       GJ Bailey    34       MR Marsh  ...        MS Wade    0
# 30       GJ Bailey    22       MR Marsh  ...        MS Wade   57
# 31         MS Wade    26      GJ Bailey  ...        TM Head   10
# 33       GJ Bailey    70        TM Head  ...    JP Faulkner    4
# 34       GJ Bailey    90        TM Head  ...    JP Faulkner    0
# 35       GJ Bailey    44        TM Head  ...    JW Hastings    8
# 36        MR Marsh     0      GJ Bailey  ...        MS Wade    0
# 42       GJ Bailey    17       MR Marsh  ...        MS Wade   38
# 43         TM Head    57       MR Marsh  ...      GJ Bailey    0
# 44       GJ Bailey    23       MR Marsh  ...        MS Wade   14
# 45         CA Lynn    16       MR Marsh  ...        MS Wade  100
# 47   PSP Handscomb    82        TM Head  ...        MS Wade    0
# 48         TM Head    51     GJ Maxwell  ...       MA Starc    0
# 49      GJ Maxwell    13        MS Wade  ...    JP Faulkner   18
# 56       SPD Smith     3  PSP Handscomb  ...        MS Wade    3
# 61       SPD Smith     4       MR Marsh  ...       TD Paine   25
# 69         CA Lynn    44       AT Carey  ...     MP Stoinis    2
# 71        SE Marsh    54  PSP Handscomb  ...     GJ Maxwell   11
# 76        SE Marsh     7     MP Stoinis  ...       AT Carey   21
# 77   PSP Handscomb   117       SE Marsh  ...      AJ Turner   21
# 78      GJ Maxwell     1     MP Stoinis  ...       AT Carey    3
# 79   PSP Handscomb    30     MP Stoinis  ...       AT Carey    0
# 80        SE Marsh    11     MP Stoinis  ...       AT Carey    0
# 81   PSP Handscomb    47     MP Stoinis  ...       AT Carey   25
# 82   PSP Handscomb     7     MP Stoinis  ...       AT Carey   55
# 83      GJ Maxwell    70     MP Stoinis  ...       AT Carey    0
# 84       SPD Smith    18     GJ Maxwell  ...       AT Carey    0
# 85       SPD Smith    73     GJ Maxwell  ...       AT Carey   45
# 87      GJ Maxwell    20       SE Marsh  ...       AT Carey   20
# 88       SPD Smith    73     GJ Maxwell  ...       AT Carey    4
# 89      GJ Maxwell    32     MP Stoinis  ...       AT Carey   11
# 90       SPD Smith    38     GJ Maxwell  ...       AT Carey   38
# 91       SPD Smith     5     MP Stoinis  ...       AT Carey   71
# 94       SPD Smith     0       AT Carey  ...        AC Agar    0
# 100      DJM Short     5  M Labuschagne  ...       AT Carey    1
# 101  M Labuschagne    21       MR Marsh  ...     GJ Maxwell   77
# 103  M Labuschagne    20       MR Marsh  ...     GJ Maxwell  108
#
#                   p8 p8-s               p9 p9-s             p10 p10-s  \
# 0        JP Faulkner    6         MA Starc    0      PJ Cummins     0
# 1        JP Faulkner    9         MA Starc    0      PJ Cummins     0
# 2       MC Henriques    4         MA Starc    1      PJ Cummins     0
# 3        JP Faulkner   50       MG Johnson    3        MA Starc     0
# 4          BJ Haddin   31       MG Johnson    0        MA Starc     0
# 6          MJ Clarke    0         MA Starc    0      MG Johnson     0
# 7          BJ Haddin   25       MG Johnson    3        MA Starc     0
# 8        JP Faulkner    0         MA Starc    0      MG Johnson     0
# 9          BJ Haddin    7       MG Johnson   27        MA Starc     0
# 10       JP Faulkner    0         MA Starc    0      MG Johnson     0
# 11           MS Wade    2         MA Starc    0      PJ Cummins     0
# 12          MR Marsh   40         MA Starc    0      PJ Cummins     0
# 13           MS Wade    1  NM Coulter-Nile    0      PJ Cummins     0
# 16           AC Agar    0         MA Starc    0      PJ Cummins     0
# 17           MS Wade    0        SM Boland    0        JS Paris     0
# 18       JP Faulkner    0        SM Boland    0        JS Paris     0
# 19       JP Faulkner   21      JW Hastings    0       SM Boland     0
# 20           MS Wade    0      JW Hastings    0   KW Richardson     0
# 23       JW Hastings   48          A Zampa    0    JR Hazlewood     0
# 25           A Zampa    0         MA Starc    0    JR Hazlewood     0
# 27       JP Faulkner    1         MA Starc    0         A Zampa     0
# 29       JP Faulkner    0         MA Starc    0    JR Hazlewood     0
# 30          MA Starc   17  NM Coulter-Nile   15         A Zampa     5
# 31       JP Faulkner    5         MA Starc    5         A Zampa     0
# 33       JW Hastings    5         MA Starc   12         A Zampa     5
# 34       JW Hastings    0         MA Starc    0         A Zampa     0
# 35          AJ Finch    0         MA Starc    0         A Zampa     0
# 36       JW Hastings    0       DJ Worrall    0         A Zampa     0
# 42        PJ Cummins    0         MA Starc   11         A Zampa     2
# 43        PJ Cummins    0         MA Starc    0     JP Faulkner     0
# 44       JP Faulkner   13         MA Starc    0      PJ Cummins     0
# 45       JP Faulkner    5       PJ Cummins   15        MA Starc    10
# 47       JP Faulkner    0       PJ Cummins    0    JR Hazlewood     0
# 48     PSP Handscomb    0       PJ Cummins    0         A Zampa     0
# 49          MA Starc    6       PJ Cummins    1         A Zampa     0
# 56        PJ Cummins    0  NM Coulter-Nile    0         A Zampa     0
# 61        PJ Cummins    3           AJ Tye    3         A Zampa     0
# 69        PJ Cummins    3         MA Starc    6         A Zampa    22
# 71     JA Richardson    0          NM Lyon    0       PM Siddle     0
# 76     JA Richardson    0       PJ Cummins    0         NM Lyon     0
# 77          AT Carey    0    JA Richardson    0  JP Behrendorff     0
# 78     JA Richardson   29       PJ Cummins   15         NM Lyon     1
# 79   NM Coulter-Nile    0    JA Richardson    0         NM Lyon     0
# 80   NM Coulter-Nile    0    JA Richardson    0         NM Lyon     0
# 81        PJ Cummins    2          NM Lyon    0         A Zampa     0
# 82   NM Coulter-Nile    2    KW Richardson    0         NM Lyon     0
# 83    JP Behrendorff    6    KW Richardson    5         NM Lyon     0
# 84   NM Coulter-Nile    0       PJ Cummins    0        MA Starc     0
# 85   NM Coulter-Nile   92       PJ Cummins    2        MA Starc     8
# 87   NM Coulter-Nile    2       PJ Cummins    2        MA Starc     3
# 88        PJ Cummins    0         MA Starc    5  JP Behrendorff     0
# 89   NM Coulter-Nile    0       PJ Cummins    0        MA Starc     0
# 90        PJ Cummins    1         MA Starc    4         NM Lyon     0
# 91        PJ Cummins   23         MA Starc    0  JP Behrendorff     0
# 94        PJ Cummins    0         MA Starc    0   KW Richardson     0
# 100       PJ Cummins   14         MA Starc    9         A Zampa     0
# 101       PJ Cummins    9         MA Starc   19         A Zampa     5
# 103       PJ Cummins    4         MA Starc   11         A Zampa     0
#
#                  p11 p11-s
# 0         XJ Doherty     0
# 1          GS Sandhu     0
# 2          GS Sandhu     0
# 3       JR Hazlewood     0
# 4       JR Hazlewood     0
# 6       JR Hazlewood     0
# 7         XJ Doherty     0
# 8       JR Hazlewood     0
# 9       JR Hazlewood     0
# 10      JR Hazlewood     0
# 11   NM Coulter-Nile     0
# 12   NM Coulter-Nile     0
# 13          MA Starc     0
# 16       JW Hastings     0
# 17      JR Hazlewood     0
# 18       JW Hastings     0
# 19     KW Richardson     0
# 20           NM Lyon     0
# 23         SM Boland     0
# 25           NM Lyon     0
# 27      JR Hazlewood     0
# 29         SM Boland     0
# 30      JR Hazlewood     0
# 31      JR Hazlewood     0
# 33      JR Hazlewood     0
# 34         SM Boland     0
# 35         SM Boland     0
# 36         SM Boland     0
# 42      JR Hazlewood     0
# 43      JR Hazlewood     0
# 44      JR Hazlewood     0
# 45        B Stanlake     1
# 47        B Stanlake     0
# 48      JR Hazlewood     0
# 49      JR Hazlewood     0
# 56     KW Richardson     0
# 61      JR Hazlewood     0
# 69      JR Hazlewood    10
# 71    JP Behrendorff     0
# 76           A Zampa     0
# 77           A Zampa     0
# 78           A Zampa     0
# 79           A Zampa     0
# 80           A Zampa     0
# 81    JP Behrendorff     0
# 82           A Zampa     0
# 83           A Zampa     0
# 84           A Zampa     0
# 85           A Zampa     0
# 87     KW Richardson     1
# 88     KW Richardson     0
# 89           A Zampa     0
# 90    JP Behrendorff     0
# 91           NM Lyon     0
# 94           A Zampa     0
# 100     JR Hazlewood     0
# 101     JR Hazlewood     0
# 103     JR Hazlewood     0
#
# [58 rows x 23 columns]

# %%
del data['Result']

# %%
data = data.reset_index(drop=True)

# %%
x = set()
print(x)
# Out:
# set()

# %%
players = ['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11']

# %%
for i in players:
    for j in range(len(data[i].unique())):
        x.add(data[i].unique()[j])

# %%
print(x)
# Out:
# {'DA Warner', 'AJ Tye', 'MR Marsh', 'MC Henriques', 'JP Behrendorff', 'TD Paine', 'TM Head', 'KW Richardson', 'BJ Haddin', 'A Zampa', 'JR Hazlewood', 'UT Khawaja', 'NM Lyon', 'AJ Finch', 'PJ Cummins', 'GJ Maxwell', 'SM Boland', 'CL White', 'SE Marsh', 'DJ Worrall', 'AC Agar', 'MP Stoinis', 'JA Burns', 'XJ Doherty', 'MJ Clarke', 'SPD Smith', 'PM Siddle', 'AJ Turner', 'B Stanlake', 'NM Coulter-Nile', 'CA Lynn', 'SR Watson', 'DJM Short', 'JW Hastings', 'AT Carey', 'JP Faulkner', 'GJ Bailey', 'JS Paris', 'JA Richardson', 'GS Sandhu', 'PSP Handscomb', 'M Labuschagne', 'MS Wade', 'MG Johnson', 'MA Starc'}

# %%
len(x)
# Out:
# 45

# %%
import itertools 
# def findsubsets(s, n): 
def findsubsets(s, n): 
    return [set(i) for i in itertools.combinations(s, n)]

# %%
sub2 = findsubsets(x,2)

# %%
len(sub2)
# Out:
# 990

# %%
for t in sub2:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        sub2.remove(t)

# %%
len(sub2)
# Out:
# 677

# %%
#load data file which includes both won lost data
data_all = pd.read_csv('aus.csv')

# %%
column_names = ["player-1", "player-2", "avg"]

result_2grams = pd.DataFrame(columns = column_names)

# %%
player_scores = ['p1-s','p2-s','p3-s','p4-s','p5-s','p6-s','p7-s','p8-s','p9-s','p10-s','p11-s']

# %%
for t in sub2:
    new_list = list(t)
    df = data_all[np.equal.outer(data_all.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':avg}, ignore_index=True)

# %%
unique_list = list(x)
print(unique_list)
# Out:
# ['DA Warner', 'AJ Tye', 'MR Marsh', 'MC Henriques', 'JP Behrendorff', 'TD Paine', 'TM Head', 'KW Richardson', 'BJ Haddin', 'A Zampa', 'JR Hazlewood', 'UT Khawaja', 'NM Lyon', 'AJ Finch', 'PJ Cummins', 'GJ Maxwell', 'SM Boland', 'CL White', 'SE Marsh', 'DJ Worrall', 'AC Agar', 'MP Stoinis', 'JA Burns', 'XJ Doherty', 'MJ Clarke', 'SPD Smith', 'PM Siddle', 'AJ Turner', 'B Stanlake', 'NM Coulter-Nile', 'CA Lynn', 'SR Watson', 'DJM Short', 'JW Hastings', 'AT Carey', 'JP Faulkner', 'GJ Bailey', 'JS Paris', 'JA Richardson', 'GS Sandhu', 'PSP Handscomb', 'M Labuschagne', 'MS Wade', 'MG Johnson', 'MA Starc']

# %%
column_names = ["player_name", "sum", "avg"]

result = pd.DataFrame(columns = column_names)

# %%
dictionary = dict()

for indx, name in enumerate(unique_list):
    count = 0
    sum = 0
    for index, row in data_all.iterrows():
        for ind, p in enumerate(players):
                if(data_all.iloc[index][p] == name ):
#                     print(name)
                    sum = sum + data_all.iloc[index][player_scores[ind]] 
                    count += 1
    avg = round((sum/count),2)
    print(name," : sum=",sum," , count=",count," , average=",round(avg,2))    
    dictionary[name] = avg
    result = result.append({'player_name':name, 'sum':sum, 'avg':avg}, ignore_index=True)
    
print(dictionary)
# Out:
# DA Warner  : sum= 3812  , count= 72  , average= 52.94
# AJ Tye  : sum= 57  , count= 7  , average= 8.14
# MR Marsh  : sum= 1255  , count= 46  , average= 27.28
# MC Henriques  : sum= 31  , count= 4  , average= 7.75
# JP Behrendorff  : sum= 19  , count= 11  , average= 1.73
# TD Paine  : sum= 153  , count= 9  , average= 17.0
# TM Head  : sum= 1273  , count= 40  , average= 31.82
# KW Richardson  : sum= 64  , count= 17  , average= 3.76
# BJ Haddin  : sum= 206  , count= 11  , average= 18.73
# A Zampa  : sum= 124  , count= 57  , average= 2.18
# JR Hazlewood  : sum= 46  , count= 41  , average= 1.12
# UT Khawaja  : sum= 1540  , count= 36  , average= 42.78
# NM Lyon  : sum= 65  , count= 21  , average= 3.1
# AJ Finch  : sum= 3505  , count= 88  , average= 39.83
# PJ Cummins  : sum= 262  , count= 56  , average= 4.68
# GJ Maxwell  : sum= 2149  , count= 71  , average= 30.27
# SM Boland  : sum= 9  , count= 13  , average= 0.69
# CL White  : sum= 35  , count= 4  , average= 8.75
# SE Marsh  : sum= 1129  , count= 29  , average= 38.93
# DJ Worrall  : sum= 6  , count= 3  , average= 2.0
# AC Agar  : sum= 189  , count= 13  , average= 14.54
# MP Stoinis  : sum= 1106  , count= 44  , average= 25.14
# JA Burns  : sum= 146  , count= 6  , average= 24.33
# XJ Doherty  : sum= 0  , count= 2  , average= 0.0
# MJ Clarke  : sum= 172  , count= 6  , average= 28.67
# SPD Smith  : sum= 3211  , count= 75  , average= 42.81
# PM Siddle  : sum= 10  , count= 3  , average= 3.33
# AJ Turner  : sum= 79  , count= 6  , average= 13.17
# B Stanlake  : sum= 4  , count= 7  , average= 0.57
# NM Coulter-Nile  : sum= 192  , count= 22  , average= 8.73
# CA Lynn  : sum= 75  , count= 4  , average= 18.75
# SR Watson  : sum= 312  , count= 11  , average= 28.36
# DJM Short  : sum= 211  , count= 8  , average= 26.38
# JW Hastings  : sum= 189  , count= 17  , average= 11.12
# AT Carey  : sum= 1015  , count= 39  , average= 26.03
# JP Faulkner  : sum= 346  , count= 33  , average= 10.48
# GJ Bailey  : sum= 1099  , count= 36  , average= 30.53
# JS Paris  : sum= 0  , count= 2  , average= 0.0
# JA Richardson  : sum= 92  , count= 13  , average= 7.08
# GS Sandhu  : sum= 0  , count= 2  , average= 0.0
# PSP Handscomb  : sum= 716  , count= 23  , average= 31.13
# M Labuschagne  : sum= 394  , count= 10  , average= 39.4
# MS Wade  : sum= 868  , count= 44  , average= 19.73
# MG Johnson  : sum= 34  , count= 8  , average= 4.25
# MA Starc  : sum= 240  , count= 61  , average= 3.93
# {'DA Warner': 52.94, 'AJ Tye': 8.14, 'MR Marsh': 27.28, 'MC Henriques': 7.75, 'JP Behrendorff': 1.73, 'TD Paine': 17.0, 'TM Head': 31.82, 'KW Richardson': 3.76, 'BJ Haddin': 18.73, 'A Zampa': 2.18, 'JR Hazlewood': 1.12, 'UT Khawaja': 42.78, 'NM Lyon': 3.1, 'AJ Finch': 39.83, 'PJ Cummins': 4.68, 'GJ Maxwell': 30.27, 'SM Boland': 0.69, 'CL White': 8.75, 'SE Marsh': 38.93, 'DJ Worrall': 2.0, 'AC Agar': 14.54, 'MP Stoinis': 25.14, 'JA Burns': 24.33, 'XJ Doherty': 0.0, 'MJ Clarke': 28.67, 'SPD Smith': 42.81, 'PM Siddle': 3.33, 'AJ Turner': 13.17, 'B Stanlake': 0.57, 'NM Coulter-Nile': 8.73, 'CA Lynn': 18.75, 'SR Watson': 28.36, 'DJM Short': 26.38, 'JW Hastings': 11.12, 'AT Carey': 26.03, 'JP Faulkner': 10.48, 'GJ Bailey': 30.53, 'JS Paris': 0.0, 'JA Richardson': 7.08, 'GS Sandhu': 0.0, 'PSP Handscomb': 31.13, 'M Labuschagne': 39.4, 'MS Wade': 19.73, 'MG Johnson': 4.25, 'MA Starc': 3.93}

# %%
result_2grams.head()
# Out:
#          player-1   player-2        avg
# 0       DA Warner     AJ Tye  22.000000
# 1        MR Marsh  DA Warner  76.358974
# 2    MC Henriques  DA Warner  19.000000
# 3  JP Behrendorff  DA Warner  73.000000
# 4       DA Warner   TD Paine  38.750000

# %%
result_2grams.shape
# Out:
# (677, 3)

# %%
result_2grams = result_2grams[result_2grams.avg != 0.0]

# %%
result_2grams.shape
# Out:
# (514, 3)

# %%
result_2grams = result_2grams.reset_index(drop=True)

# %%
new_column_names = ["player-1", "player-2", "combined_avg","sum_of_individual"]

afg_beautiful2grams = pd.DataFrame(columns = new_column_names)

# %%
for index, row in result_2grams.iterrows():
    player1 = result_2grams.iloc[index]['player-1']
    player2 = result_2grams.iloc[index]['player-2']
    combined = result_2grams.iloc[index]['avg']
    individual_avg_sum = dictionary.get(player1)+dictionary.get(player2)
    if(combined > individual_avg_sum):
        afg_beautiful2grams = afg_beautiful2grams.append({'player-1':player1, 'player-2':player2, 'combined_avg': combined, 'sum_of_individual':individual_avg_sum}, ignore_index=True)

# %%
afg_beautiful2grams.head()
# Out:
#          player-1       player-2  combined_avg  sum_of_individual
# 0  JP Behrendorff      DA Warner     73.000000              54.67
# 1       DA Warner        TM Head     88.965517              84.76
# 2       DA Warner  KW Richardson     72.300000              56.70
# 3       DA Warner     UT Khawaja    102.000000              95.72
# 4       DA Warner        NM Lyon     57.111111              56.04

# %%
afg_beautiful2grams.shape
# Out:
# (242, 4)

# %%
afg_beautiful2grams.to_csv('aus2grams_won.csv')
