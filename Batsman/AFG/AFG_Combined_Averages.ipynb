# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data file
data = pd.read_csv('afg.csv')

# %%
data.head()
# Out:
#              p1  p1-s             p2  p2-s             p3  p3-s  \
# 0  Javed Ahmadi    81    Usman Ghani     1    Afsar Zazai     1
# 1  Javed Ahmadi    13    Usman Ghani     6  Asghar Afghan    44
# 2  Javed Ahmadi     1    Afsar Zazai     1  Nawroz Mangal    27
# 3  Javed Ahmadi    24  Nawroz Mangal    10  Asghar Afghan    54
# 4  Javed Ahmadi    13    Usman Ghani    12  Nawroz Mangal    33
#
#                    p4  p4-s                  p5  p5-s  ...                 p7  \
# 0         Nasir Jamal     8       Asghar Afghan     8  ...  Najibullah Zadran
# 1  Samiullah Shinwari    50       Mohammad Nabi     9  ...        Afsar Zazai
# 2       Asghar Afghan     1  Samiullah Shinwari    42  ...  Najibullah Zadran
# 3  Samiullah Shinwari    38       Mohammad Nabi    21  ...        Afsar Zazai
# 4       Asghar Afghan     4  Samiullah Shinwari    17  ...  Najibullah Zadran
#
#    p7-s              p8  p8-s             p9  p9-s           p10  p10-s  \
# 0    45  Mirwais Ashraf    12  Dawlat Zadran    11  Hamid Hassan      0
# 1    18  Mirwais Ashraf     5  Dawlat Zadran     2    Aftab Alam      2
# 2    17  Mirwais Ashraf    10     Aftab Alam    14  Hamid Hassan      0
# 3    19  Mirwais Ashraf    28  Dawlat Zadran     4  Hamid Hassan      0
# 4    24     Afsar Zazai    10  Dawlat Zadran     0  Hamid Hassan      7
#
#               p11  p11-s
# 0      Aftab Alam      0
# 1    Hamid Hassan      0
# 2  Shapoor Zadran      2
# 3  Shapoor Zadran      1
# 4  Shapoor Zadran      0
#
# [5 rows x 22 columns]

# %%
x = set()
print(x)
# Out:
# set()

# %%
players = ['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11']

# %%
for i in players:
    for j in range(len(data[i].unique())):
        x.add(data[i].unique()[j])

# %%
print(x)
# Out:
# {'Samiullah Shinwari', 'Shabir Noori', 'Karim Janat', 'Sharafuddin Ashraf', 'Rahmat Shah', 'Najibullah Zadran', 'Dawlat Zadran', 'Zahir Khan', 'Mohammad Nabi', 'Hashmatullah Shahidi', 'Ihsanullah', 'Shapoor Zadran', 'Amir Hamza', 'Aftab Alam', 'Usman Ghani', 'Hazratullah Zazai', 'Karim Sadiq', 'Rokhan Barakzai', 'Nawroz Mangal', 'Ibrahim Zadran', 'Fareed Ahmad', 'Sayed Shirzad', 'Rashid Khan', 'Gulbadin Naib', 'Naveen-ul-Haq', 'Noor Ali Zadran', 'Mohammad Shahzad', 'Asghar Afghan', 'Javed Ahmadi', 'Shafiqullah', 'Yamin Ahmadzai', 'Mirwais Ashraf', 'Mujeeb Ur Rahman', 'Nasir Jamal', 'Ikram Alikhil', 'Afsar Zazai', 'Najeeb Tarakai', 'Hamid Hassan'}

# %%
player_scores = ['p1-s','p2-s','p3-s','p4-s','p5-s','p6-s','p7-s','p8-s','p9-s','p10-s','p11-s']

# %%
print(len(x))
# Out:
# 38

# %%
import itertools 
# def findsubsets(s, n): 
def findsubsets(s, n): 
    return [set(i) for i in itertools.combinations(s, n)]

# %%
sub2 = findsubsets(x,2)

# %%
## 2- grams

# %%
column_names = ["player-1", "player-2", "avg"]

result_2grams = pd.DataFrame(columns = column_names)

# %%
for t in sub2:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':avg}, ignore_index=True)

# %%
result_2grams.head(25)
# Out:
#           player-1            player-2    avg
# 0   Najeeb Tarakai      Mirwais Ashraf    0.0
# 1   Najeeb Tarakai          Zahir Khan    0.0
# 2   Najeeb Tarakai   Najibullah Zadran    0.0
# 3   Najeeb Tarakai         Karim Sadiq    0.0
# 4   Najeeb Tarakai     Rokhan Barakzai    0.0
# 5   Najeeb Tarakai        Shabir Noori    0.0
# 6   Najeeb Tarakai         Afsar Zazai    0.0
# 7   Najeeb Tarakai        Hamid Hassan    0.0
# 8   Najeeb Tarakai        Javed Ahmadi    0.0
# 9   Najeeb Tarakai   Hazratullah Zazai    0.0
# 10  Najeeb Tarakai        Fareed Ahmad    5.0
# 11  Najeeb Tarakai          Amir Hamza    0.0
# 12  Najeeb Tarakai  Samiullah Shinwari   67.0
# 13  Najeeb Tarakai       Asghar Afghan   44.0
# 14  Najeeb Tarakai       Ikram Alikhil    0.0
# 15  Najeeb Tarakai         Karim Janat    0.0
# 16  Najeeb Tarakai         Usman Ghani    0.0
# 17  Najeeb Tarakai          Ihsanullah    0.0
# 18  Najeeb Tarakai         Nasir Jamal    0.0
# 19  Najeeb Tarakai         Rashid Khan    5.0
# 20  Najeeb Tarakai         Rahmat Shah  113.0
# 21  Najeeb Tarakai       Naveen-ul-Haq    0.0
# 22  Najeeb Tarakai      Ibrahim Zadran    0.0
# 23  Najeeb Tarakai  Sharafuddin Ashraf    0.0
# 24  Najeeb Tarakai      Yamin Ahmadzai    0.0

# %%
result_2grams.to_csv('afg2grams.csv')

# %%
# 3-grams

# %%
sub3 = findsubsets(x,3)

# %%
column_names = ["player-1", "player-2","player-3", "avg"]

result_3grams = pd.DataFrame(columns = column_names)

# %%
for t in sub3:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_3grams = result_3grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[2] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_3grams = result_3grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'avg':avg}, ignore_index=True)

# %%
result_3grams.head(25)
# Out:
#           player-1            player-2           player-3  avg
# 0   Najeeb Tarakai      Mirwais Ashraf         Zahir Khan  0.0
# 1   Najeeb Tarakai      Mirwais Ashraf  Najibullah Zadran  0.0
# 2   Najeeb Tarakai      Mirwais Ashraf        Karim Sadiq  0.0
# 3   Najeeb Tarakai      Mirwais Ashraf    Rokhan Barakzai  0.0
# 4   Najeeb Tarakai        Shabir Noori     Mirwais Ashraf  0.0
# 5   Najeeb Tarakai         Afsar Zazai     Mirwais Ashraf  0.0
# 6   Najeeb Tarakai        Hamid Hassan     Mirwais Ashraf  0.0
# 7   Najeeb Tarakai        Javed Ahmadi     Mirwais Ashraf  0.0
# 8   Najeeb Tarakai   Hazratullah Zazai     Mirwais Ashraf  0.0
# 9   Najeeb Tarakai        Fareed Ahmad     Mirwais Ashraf  0.0
# 10  Najeeb Tarakai          Amir Hamza     Mirwais Ashraf  0.0
# 11  Najeeb Tarakai  Samiullah Shinwari     Mirwais Ashraf  0.0
# 12  Najeeb Tarakai      Mirwais Ashraf      Asghar Afghan  0.0
# 13  Najeeb Tarakai       Ikram Alikhil     Mirwais Ashraf  0.0
# 14  Najeeb Tarakai      Mirwais Ashraf        Karim Janat  0.0
# 15  Najeeb Tarakai         Usman Ghani     Mirwais Ashraf  0.0
# 16  Najeeb Tarakai          Ihsanullah     Mirwais Ashraf  0.0
# 17  Najeeb Tarakai      Mirwais Ashraf        Nasir Jamal  0.0
# 18  Najeeb Tarakai      Mirwais Ashraf        Rashid Khan  0.0
# 19  Najeeb Tarakai         Rahmat Shah     Mirwais Ashraf  0.0
# 20  Najeeb Tarakai       Naveen-ul-Haq     Mirwais Ashraf  0.0
# 21  Najeeb Tarakai      Ibrahim Zadran     Mirwais Ashraf  0.0
# 22  Najeeb Tarakai  Sharafuddin Ashraf     Mirwais Ashraf  0.0
# 23  Najeeb Tarakai      Mirwais Ashraf     Yamin Ahmadzai  0.0
# 24  Najeeb Tarakai       Dawlat Zadran     Mirwais Ashraf  0.0

# %%
result_3grams.to_csv('afg3grams.csv')

# %%
#4 grams

# %%
sub4 = findsubsets(x,4)

# %%
column_names = ["player-1", "player-2","player-3", "player-4", "avg"]

result_4grams = pd.DataFrame(columns = column_names)

# %%
for t in sub4:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_4grams = result_4grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[2] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[3] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_4grams = result_4grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'avg':avg}, ignore_index=True)

# %%
result_4grams.head(25)
# Out:
#           player-1            player-2        player-3           player-4  avg
# 0   Najeeb Tarakai      Mirwais Ashraf      Zahir Khan  Najibullah Zadran  0.0
# 1   Najeeb Tarakai         Karim Sadiq  Mirwais Ashraf         Zahir Khan  0.0
# 2   Najeeb Tarakai      Mirwais Ashraf      Zahir Khan    Rokhan Barakzai  0.0
# 3   Najeeb Tarakai        Shabir Noori  Mirwais Ashraf         Zahir Khan  0.0
# 4   Najeeb Tarakai         Afsar Zazai  Mirwais Ashraf         Zahir Khan  0.0
# 5   Najeeb Tarakai        Hamid Hassan  Mirwais Ashraf         Zahir Khan  0.0
# 6   Najeeb Tarakai        Javed Ahmadi  Mirwais Ashraf         Zahir Khan  0.0
# 7   Najeeb Tarakai   Hazratullah Zazai  Mirwais Ashraf         Zahir Khan  0.0
# 8   Najeeb Tarakai        Fareed Ahmad  Mirwais Ashraf         Zahir Khan  0.0
# 9   Najeeb Tarakai          Amir Hamza  Mirwais Ashraf         Zahir Khan  0.0
# 10  Najeeb Tarakai  Samiullah Shinwari  Mirwais Ashraf         Zahir Khan  0.0
# 11  Najeeb Tarakai      Mirwais Ashraf      Zahir Khan      Asghar Afghan  0.0
# 12  Najeeb Tarakai       Ikram Alikhil  Mirwais Ashraf         Zahir Khan  0.0
# 13  Najeeb Tarakai      Mirwais Ashraf      Zahir Khan        Karim Janat  0.0
# 14  Najeeb Tarakai         Usman Ghani  Mirwais Ashraf         Zahir Khan  0.0
# 15  Najeeb Tarakai          Ihsanullah  Mirwais Ashraf         Zahir Khan  0.0
# 16  Najeeb Tarakai      Mirwais Ashraf      Zahir Khan        Nasir Jamal  0.0
# 17  Najeeb Tarakai      Mirwais Ashraf      Zahir Khan        Rashid Khan  0.0
# 18  Najeeb Tarakai         Rahmat Shah  Mirwais Ashraf         Zahir Khan  0.0
# 19  Najeeb Tarakai       Naveen-ul-Haq  Mirwais Ashraf         Zahir Khan  0.0
# 20  Najeeb Tarakai      Ibrahim Zadran  Mirwais Ashraf         Zahir Khan  0.0
# 21  Najeeb Tarakai  Sharafuddin Ashraf  Mirwais Ashraf         Zahir Khan  0.0
# 22  Najeeb Tarakai      Mirwais Ashraf      Zahir Khan     Yamin Ahmadzai  0.0
# 23  Najeeb Tarakai       Dawlat Zadran  Mirwais Ashraf         Zahir Khan  0.0
# 24  Najeeb Tarakai      Mirwais Ashraf      Zahir Khan      Gulbadin Naib  0.0

# %%
result_4grams.to_csv('afg4grams.csv')

# %%
#5-grams

# %%
sub5 = findsubsets(x,5)

# %%
column_names = ["player-1", "player-2","player-3", "player-4", "player-5", "avg"]

result_5grams = pd.DataFrame(columns = column_names)

# %%
for t in sub5:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_5grams = result_5grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'player-5':new_list[4], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[2] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[3] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[4] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_5grams = result_5grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'player-5':new_list[4], 'avg':avg}, ignore_index=True)

# %%
result_5grams.head(25)
# Out:
#           player-1           player-2        player-3           player-4  \
# 0   Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 1   Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 2   Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 3   Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 4   Najeeb Tarakai       Hamid Hassan  Mirwais Ashraf         Zahir Khan
# 5   Najeeb Tarakai       Javed Ahmadi  Mirwais Ashraf         Zahir Khan
# 6   Najeeb Tarakai  Hazratullah Zazai  Mirwais Ashraf         Zahir Khan
# 7   Najeeb Tarakai       Fareed Ahmad  Mirwais Ashraf         Zahir Khan
# 8   Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 9   Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 10  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 11  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 12  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 13  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 14  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 15  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 16  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 17  Najeeb Tarakai        Rahmat Shah  Mirwais Ashraf         Zahir Khan
# 18  Najeeb Tarakai      Naveen-ul-Haq  Mirwais Ashraf         Zahir Khan
# 19  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 20  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 21  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 22  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 23  Najeeb Tarakai     Mirwais Ashraf      Zahir Khan  Najibullah Zadran
# 24  Najeeb Tarakai      Mohammad Nabi  Mirwais Ashraf         Zahir Khan
#
#               player-5  avg
# 0          Karim Sadiq  0.0
# 1      Rokhan Barakzai  0.0
# 2         Shabir Noori  0.0
# 3          Afsar Zazai  0.0
# 4    Najibullah Zadran  0.0
# 5    Najibullah Zadran  0.0
# 6    Najibullah Zadran  0.0
# 7    Najibullah Zadran  0.0
# 8           Amir Hamza  0.0
# 9   Samiullah Shinwari  0.0
# 10       Asghar Afghan  0.0
# 11       Ikram Alikhil  0.0
# 12         Karim Janat  0.0
# 13         Usman Ghani  0.0
# 14          Ihsanullah  0.0
# 15         Nasir Jamal  0.0
# 16         Rashid Khan  0.0
# 17   Najibullah Zadran  0.0
# 18   Najibullah Zadran  0.0
# 19      Ibrahim Zadran  0.0
# 20  Sharafuddin Ashraf  0.0
# 21      Yamin Ahmadzai  0.0
# 22       Dawlat Zadran  0.0
# 23       Gulbadin Naib  0.0
# 24   Najibullah Zadran  0.0

# %%
result_5grams.to_csv('afg5grams.csv')

# %%
#6 grams

# %%
sub6 = findsubsets(x,6)

# %%
column_names = ["player-1", "player-2","player-3", "player-4", "player-5", "player-6", "avg"]

result_6grams = pd.DataFrame(columns = column_names)

# %%
print(len(sub6))
# Out:
# 2760681

# %%
print(len(sub4))
# Out:
# 73815

# %%
for t in sub6:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_6grams = result_6grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'player-5':new_list[4], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[2] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[3] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[4] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[5] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_6grams = result_6grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'player-5':new_list[4], 'avg':avg}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e2d92f2f8841> in <module>
#       6     isempty = df.empty
#       7     if(isempty):
# ----> 8         result_6grams = result_6grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'player-3':new_list[2], 'player-4':new_list[3], 'player-5':new_list[4], 'avg':0.0}, ignore_index=True)
#       9         continue
#      10     for index, row in df.iterrows():
#
# c:\python\python38\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7079         else:
#    7080             to_concat = [self, other]
# -> 7081         return concat(
#    7082             to_concat,
#    7083             ignore_index=ignore_index,
#
# c:\python\python38\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# c:\python\python38\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     494                 mgrs_indexers.append((obj._data, indexers))
#     495
# --> 496             new_data = concatenate_block_managers(
#     497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#
# c:\python\python38\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2015             b = b.make_block_same_class(values, placement=placement)
#    2016         elif is_uniform_join_units(join_units):
# -> 2017             b = join_units[0].block.concat_same_type(
#    2018                 [ju.block for ju in join_units], placement=placement
#    2019             )
#
# c:\python\python38\lib\site-packages\pandas\core\internals\blocks.py in concat_same_type(self, to_concat, placement)
#     356         Concatenate list of single blocks of the same type.
#     357         """
# --> 358         values = self._concatenator(
#     359             [blk.values for blk in to_concat], axis=self.ndim - 1
#     360         )
#
# KeyboardInterrupt:
