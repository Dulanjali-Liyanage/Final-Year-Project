# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data file
data = pd.read_csv('bdesh_data.csv')

# %%
data.head()
# Out:
#   Result            p1  p1-s            p2  p2-s             p3  p3-s  \
# 0    won  Anamul Haque    29   Tamim Iqbal    19  Soumya Sarkar    28
# 1   lost   Tamim Iqbal     0  Anamul Haque    29  Soumya Sarkar    25
# 2    won   Tamim Iqbal     2   Imrul Kayes     2  Soumya Sarkar    40
# 3   lost   Tamim Iqbal    13   Imrul Kayes     2  Soumya Sarkar    51
# 4   lost   Tamim Iqbal    25   Imrul Kayes     5  Soumya Sarkar    29
#
#               p4  p4-s               p5  ...               p7 p7-s  \
# 0    Mahmudullah    23  Shakib Al Hasan  ...    Sabbir Rahman    3
# 1  Mominul Haque     1      Mahmudullah  ...  Mushfiqur Rahim   36
# 2    Mahmudullah   103  Shakib Al Hasan  ...    Sabbir Rahman   14
# 3    Mahmudullah   128  Shakib Al Hasan  ...    Sabbir Rahman   40
# 4    Mahmudullah    21  Shakib Al Hasan  ...    Sabbir Rahman   30
#
#                  p8 p8-s                p9 p9-s            p10 p10-s  \
# 0  Mashrafe Mortaza   14   Mushfiqur Rahim    3  Rubel Hossain     0
# 1     Sabbir Rahman   53  Mashrafe Mortaza    7  Rubel Hossain     0
# 2  Mashrafe Mortaza    6      Arafat Sunny    3  Rubel Hossain     0
# 3     Nasir Hossain   11     Rubel Hossain    0   Taijul Islam     0
# 4     Nasir Hossain   35  Mashrafe Mortaza    1  Rubel Hossain     0
#
#             p11 p11-s
# 0  Taskin Ahmed     1
# 1  Taskin Ahmed     0
# 2  Taskin Ahmed     0
# 3  Taskin Ahmed     0
# 4  Taskin Ahmed     0
#
# [5 rows x 23 columns]

# %%
data = data[data.Result == 'won']

# %%
data
# Out:
#    Result            p1  p1-s                     p2  p2-s  \
# 0     won  Anamul Haque    29            Tamim Iqbal    19
# 2     won   Tamim Iqbal     2            Imrul Kayes     2
# 5     won   Tamim Iqbal   132          Soumya Sarkar    20
# 6     won   Tamim Iqbal   116          Soumya Sarkar    17
# 7     won   Tamim Iqbal    64          Soumya Sarkar   127
# 8     won   Tamim Iqbal    60          Soumya Sarkar    54
# 9     won   Tamim Iqbal    13          Soumya Sarkar    34
# 12    won   Tamim Iqbal     5          Soumya Sarkar    88
# 13    won   Tamim Iqbal    61          Soumya Sarkar    90
# 14    won   Tamim Iqbal    40              Liton Das     0
# 15    won   Tamim Iqbal    19            Imrul Kayes    76
# 16    won   Tamim Iqbal    73            Imrul Kayes    73
# 17    won   Tamim Iqbal    80          Soumya Sarkar     0
# 19    won   Tamim Iqbal   118          Soumya Sarkar    11
# 21    won   Tamim Iqbal    14            Imrul Kayes    11
# 26    won   Tamim Iqbal   127          Soumya Sarkar    10
# 29    won   Tamim Iqbal    47          Soumya Sarkar    87
# 30    won   Tamim Iqbal    65          Soumya Sarkar     0
# 32    won   Tamim Iqbal     0          Soumya Sarkar     3
# 37    won   Tamim Iqbal    84           Anamul Haque    19
# 38    won   Tamim Iqbal    84           Anamul Haque    35
# 39    won   Tamim Iqbal    76           Anamul Haque     1
# 42    won   Tamim Iqbal   130           Anamul Haque     0
# 44    won   Tamim Iqbal   103           Anamul Haque    10
# 45    won   Tamim Iqbal     2              Liton Das     0
# 48    won     Liton Das    41  Najmul Hossain Shanto     6
# 49    won     Liton Das     6          Soumya Sarkar     0
# 51    won     Liton Das     4            Imrul Kayes   144
# 52    won     Liton Das    83            Imrul Kayes    90
# 53    won     Liton Das     0            Imrul Kayes   115
# 54    won   Tamim Iqbal    12              Liton Das    41
# 56    won   Tamim Iqbal    81              Liton Das    23
# 60    won   Tamim Iqbal    80          Soumya Sarkar    73
# 61    won   Tamim Iqbal    21          Soumya Sarkar    54
# 62    won   Tamim Iqbal    57              Liton Das    76
# 63    won   Tamim Iqbal    18          Soumya Sarkar    66
# 64    won   Tamim Iqbal    16          Soumya Sarkar    42
# 67    won   Tamim Iqbal    48          Soumya Sarkar    29
# 69    won     Liton Das    16            Tamim Iqbal    36
# 75    won     Liton Das   126            Tamim Iqbal    24
# 76    won   Tamim Iqbal   158              Liton Das     9
# 77    won   Tamim Iqbal   128              Liton Das   176
#
#                        p3  p3-s                p4  p4-s               p5  ...  \
# 0           Soumya Sarkar    28       Mahmudullah    23  Shakib Al Hasan  ...
# 2           Soumya Sarkar    40       Mahmudullah   103  Shakib Al Hasan  ...
# 5             Mahmudullah     5   Mushfiqur Rahim   106  Shakib Al Hasan  ...
# 6             Mahmudullah    17   Mushfiqur Rahim    65  Shakib Al Hasan  ...
# 7             Mahmudullah     4   Mushfiqur Rahim    49    Sabbir Rahman  ...
# 8               Liton Das     8   Mushfiqur Rahim    14  Shakib Al Hasan  ...
# 9               Liton Das    36   Mushfiqur Rahim    31  Shakib Al Hasan  ...
# 12              Liton Das    17       Mahmudullah    50  Shakib Al Hasan  ...
# 13              Liton Das     5   Mushfiqur Rahim     0    Sabbir Rahman  ...
# 14            Mahmudullah     9   Mushfiqur Rahim   107  Shakib Al Hasan  ...
# 15              Liton Das     7       Mahmudullah     4  Mushfiqur Rahim  ...
# 16        Mushfiqur Rahim    28         Liton Das    17      Mahmudullah  ...
# 17            Imrul Kayes    37       Mahmudullah    62  Shakib Al Hasan  ...
# 19          Sabbir Rahman    65   Shakib Al Hasan    17  Mushfiqur Rahim  ...
# 21          Sabbir Rahman     3       Mahmudullah    75  Mushfiqur Rahim  ...
# 26          Sabbir Rahman    54   Mushfiqur Rahim     1  Shakib Al Hasan  ...
# 29          Sabbir Rahman    35   Mushfiqur Rahim     3  Shakib Al Hasan  ...
# 30          Sabbir Rahman    65  Mosaddek Hossain    10  Mushfiqur Rahim  ...
# 32          Sabbir Rahman     8   Mushfiqur Rahim    14  Shakib Al Hasan  ...
# 37        Shakib Al Hasan    37   Mushfiqur Rahim    14      Mahmudullah  ...
# 38        Shakib Al Hasan    67   Mushfiqur Rahim    62      Mahmudullah  ...
# 39        Shakib Al Hasan    51   Mushfiqur Rahim    18      Mahmudullah  ...
# 42        Shakib Al Hasan    97     Sabbir Rahman     3  Mushfiqur Rahim  ...
# 44        Shakib Al Hasan    37   Mushfiqur Rahim    12      Mahmudullah  ...
# 45        Shakib Al Hasan     0   Mushfiqur Rahim   144  Mohammad Mithun  ...
# 48        Mohammad Mithun     1   Mushfiqur Rahim    33  Shakib Al Hasan  ...
Mashrafe Mortaza     0   Mustafizur Rahman     0
# 30   Mustafizur Rahman     0       Rubel Hossain     0
# 32       Rubel Hossain     0   Mustafizur Rahman     0
# 37   Mustafizur Rahman     0       Rubel Hossain     0
# 38       Rubel Hossain     0   Mustafizur Rahman     0
# 39   Mustafizur Rahman    18       Rubel Hossain     8
# 42       Rubel Hossain     0   Mustafizur Rahman     0
# 44       Rubel Hossain     0   Mustafizur Rahman     0
# 45       Rubel Hossain     2   Mustafizur Rahman    10
# 48   Mustafizur Rahman     0        Nazmul Islam     0
# 49       Rubel Hossain     1   Mustafizur Rahman     0
# 51   Mustafizur Rahman     1        Nazmul Islam     0
# 52   Mustafizur Rahman     0        Nazmul Islam     0
# 53  Mohammad Saifuddin     0           Abu Hider     0
# 54   Mustafizur Rahman     0       Rubel Hossain     0
# 56  Mohammad Saifuddin     0   Mustafizur Rahman     0
# 60  Mehidy Hasan Miraz     0   Mustafizur Rahman     0
# 61    Mashrafe Mortaza     0   Mustafizur Rahman     0
# 62           Abu Jayed     0  Mohammad Saifuddin     0
# 63    Mashrafe Mortaza     0   Mustafizur Rahman     0
# 64    Mashrafe Mortaza     0   Mustafizur Rahman     0
# 67    Mashrafe Mortaza     0   Mustafizur Rahman     0
# 69    Mashrafe Mortaza     0   Mustafizur Rahman     0
# 75        Taijul Islam     0   Mustafizur Rahman     0
# 76       Shafiul Islam     5     Al-Amin Hossain     0
# 77  Mohammad Saifuddin     0   Mustafizur Rahman     0
#
# [42 rows x 23 columns]

# %%
del data['Result']

# %%
data = data.reset_index(drop=True)

# %%
x = set()
print(x)
# Out:
# set()

# %%
players = ['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11']

# %%
for i in players:
    for j in range(len(data[i].unique())):
        x.add(data[i].unique()[j])

# %%
print(x)
# Out:
# {'Taskin Ahmed', 'Mosharraf Hossain', 'Mohammad Mithun', 'Abu Hider', 'Arafat Sunny', 'Liton Das', 'Nasir Hossain', 'Fazle Mahmud', 'Abul Hasan', 'Sunzamul Islam', 'Anamul Haque', 'Imrul Kayes', 'Mohammad Saifuddin', 'Afif Hossain', 'Taijul Islam', 'Mominul Haque', 'Ariful Haque', 'Rubel Hossain', 'Mushfiqur Rahim', 'Mehidy Hasan Miraz', 'Sabbir Rahman', 'Soumya Sarkar', 'Mashrafe Mortaza', 'Tamim Iqbal', 'Mahmudullah', 'Mohammad Naim', 'Nazmul Islam', 'Shakib Al Hasan', 'Najmul Hossain Shanto', 'Al-Amin Hossain', 'Abu Jayed', 'Mosaddek Hossain', 'Mustafizur Rahman', 'Shafiul Islam'}

# %%
len(x)
# Out:
# 34

# %%
import itertools 
# def findsubsets(s, n): 
def findsubsets(s, n): 
    return [set(i) for i in itertools.combinations(s, n)]

# %%
sub2 = findsubsets(x,2)

# %%
len(sub2)
# Out:
# 561

# %%
for t in sub2:
    new_list = list(t)
    df = data[np.equal.outer(data.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        sub2.remove(t)

# %%
len(sub2)
# Out:
# 416

# %%
#load data file which includes both won lost data
data_all = pd.read_csv('bdesh.csv')

# %%
column_names = ["player-1", "player-2", "avg"]

result_2grams = pd.DataFrame(columns = column_names)

# %%
player_scores = ['p1-s','p2-s','p3-s','p4-s','p5-s','p6-s','p7-s','p8-s','p9-s','p10-s','p11-s']

# %%
for t in sub2:
    new_list = list(t)
    df = data_all[np.equal.outer(data_all.to_numpy(copy=False),  new_list).any(axis=1).all(axis=1)]
    count = 0;
    df = df.reset_index(drop=True)
    isempty = df.empty
    if(isempty):
        result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':0.0}, ignore_index=True)
        continue
    for index, row in df.iterrows():
        for ind, p in enumerate(players):
                if(df.iloc[index][p] == new_list[0] ):
                    count = count + df.iloc[index][player_scores[ind]]
                if(df.iloc[index][p] == new_list[1] ):
                    count = count + df.iloc[index][player_scores[ind]]
    avg = count/df.shape[0]
    result_2grams = result_2grams.append({'player-1':new_list[0], 'player-2':new_list[1], 'avg':avg}, ignore_index=True)

# %%
unique_list = list(x)
print(unique_list)
# Out:
# ['Taskin Ahmed', 'Mosharraf Hossain', 'Mohammad Mithun', 'Abu Hider', 'Arafat Sunny', 'Liton Das', 'Nasir Hossain', 'Fazle Mahmud', 'Abul Hasan', 'Sunzamul Islam', 'Anamul Haque', 'Imrul Kayes', 'Mohammad Saifuddin', 'Afif Hossain', 'Taijul Islam', 'Mominul Haque', 'Ariful Haque', 'Rubel Hossain', 'Mushfiqur Rahim', 'Mehidy Hasan Miraz', 'Sabbir Rahman', 'Soumya Sarkar', 'Mashrafe Mortaza', 'Tamim Iqbal', 'Mahmudullah', 'Mohammad Naim', 'Nazmul Islam', 'Shakib Al Hasan', 'Najmul Hossain Shanto', 'Al-Amin Hossain', 'Abu Jayed', 'Mosaddek Hossain', 'Mustafizur Rahman', 'Shafiul Islam']

# %%
column_names = ["player_name", "sum", "avg"]

result = pd.DataFrame(columns = column_names)

# %%
dictionary = dict()

for indx, name in enumerate(unique_list):
    count = 0
    sum = 0
    for index, row in data_all.iterrows():
        for ind, p in enumerate(players):
                if(data_all.iloc[index][p] == name ):
#                     print(name)
                    sum = sum + data_all.iloc[index][player_scores[ind]] 
                    count += 1
    avg = round((sum/count),2)
    print(name," : sum=",sum," , count=",count," , average=",round(avg,2))    
    dictionary[name] = avg
    result = result.append({'player_name':name, 'sum':sum, 'avg':avg}, ignore_index=True)
    
print(dictionary)
# Out:
# Taskin Ahmed  : sum= 41  , count= 26  , average= 1.58
# Mosharraf Hossain  : sum= 11  , count= 2  , average= 5.5
# Mohammad Mithun  : sum= 549  , count= 25  , average= 21.96
# Abu Hider  : sum= 1  , count= 2  , average= 0.5
# Arafat Sunny  : sum= 38  , count= 8  , average= 4.75
# Liton Das  : sum= 1079  , count= 36  , average= 29.97
# Nasir Hossain  : sum= 237  , count= 23  , average= 10.3
# Fazle Mahmud  : sum= 0  , count= 2  , average= 0.0
# Abul Hasan  : sum= 7  , count= 2  , average= 3.5
# Sunzamul Islam  : sum= 19  , count= 3  , average= 6.33
# Anamul Haque  : sum= 160  , count= 10  , average= 16.0
# Imrul Kayes  : sum= 1038  , count= 24  , average= 43.25
# Mohammad Saifuddin  : sum= 290  , count= 22  , average= 13.18
# Afif Hossain  : sum= 7  , count= 1  , average= 7.0
# Taijul Islam  : sum= 63  , count= 8  , average= 7.88
# Mominul Haque  : sum= 15  , count= 3  , average= 5.0
# Ariful Haque  : sum= 0  , count= 1  , average= 0.0
# Rubel Hossain  : sum= 57  , count= 45  , average= 1.27
# Mushfiqur Rahim  : sum= 2942  , count= 75  , average= 39.23
# Mehidy Hasan Miraz  : sum= 379  , count= 38  , average= 9.97
# Sabbir Rahman  : sum= 1200  , count= 57  , average= 21.05
# Soumya Sarkar  : sum= 1698  , count= 50  , average= 33.96
# Mashrafe Mortaza  : sum= 441  , count= 73  , average= 6.04
# Tamim Iqbal  : sum= 2977  , count= 68  , average= 43.78
# Mahmudullah  : sum= 1824  , count= 74  , average= 24.65
# Mohammad Naim  : sum= 0  , count= 1  , average= 0.0
# Nazmul Islam  : sum= 7  , count= 5  , average= 1.4
# Shakib Al Hasan  : sum= 2221  , count= 61  , average= 36.41
# Najmul Hossain Shanto  : sum= 55  , count= 5  , average= 11.0
# Al-Amin Hossain  : sum= 1  , count= 4  , average= 0.25
# Abu Jayed  : sum= 0  , count= 2  , average= 0.0
# Mosaddek Hossain  : sum= 549  , count= 33  , average= 16.64
# Mustafizur Rahman  : sum= 77  , count= 55  , average= 1.4
# Shafiul Islam  : sum= 10  , count= 8  , average= 1.25
# {'Taskin Ahmed': 1.58, 'Mosharraf Hossain': 5.5, 'Mohammad Mithun': 21.96, 'Abu Hider': 0.5, 'Arafat Sunny': 4.75, 'Liton Das': 29.97, 'Nasir Hossain': 10.3, 'Fazle Mahmud': 0.0, 'Abul Hasan': 3.5, 'Sunzamul Islam': 6.33, 'Anamul Haque': 16.0, 'Imrul Kayes': 43.25, 'Mohammad Saifuddin': 13.18, 'Afif Hossain': 7.0, 'Taijul Islam': 7.88, 'Mominul Haque': 5.0, 'Ariful Haque': 0.0, 'Rubel Hossain': 1.27, 'Mushfiqur Rahim': 39.23, 'Mehidy Hasan Miraz': 9.97, 'Sabbir Rahman': 21.05, 'Soumya Sarkar': 33.96, 'Mashrafe Mortaza': 6.04, 'Tamim Iqbal': 43.78, 'Mahmudullah': 24.65, 'Mohammad Naim': 0.0, 'Nazmul Islam': 1.4, 'Shakib Al Hasan': 36.41, 'Najmul Hossain Shanto': 11.0, 'Al-Amin Hossain': 0.25, 'Abu Jayed': 0.0, 'Mosaddek Hossain': 16.64, 'Mustafizur Rahman': 1.4, 'Shafiul Islam': 1.25}

# %%
result_2grams.head()
# Out:
#        player-1           player-2        avg
# 0  Taskin Ahmed  Mosharraf Hossain   6.000000
# 1  Taskin Ahmed          Abu Hider   0.000000
# 2  Taskin Ahmed       Arafat Sunny   0.750000
# 3  Taskin Ahmed          Liton Das  18.400000
# 4  Taskin Ahmed      Nasir Hossain  12.090909

# %%
result_2grams.shape
# Out:
# (416, 3)

# %%
result_2grams = result_2grams[result_2grams.avg != 0.0]

# %%
result_2grams.shape
# Out:
# (316, 3)

# %%
result_2grams = result_2grams.reset_index(drop=True)

# %%
new_column_names = ["player-1", "player-2", "combined_avg","sum_of_individual"]

afg_beautiful2grams = pd.DataFrame(columns = new_column_names)

# %%
for index, row in result_2grams.iterrows():
    player1 = result_2grams.iloc[index]['player-1']
    player2 = result_2grams.iloc[index]['player-2']
    combined = result_2grams.iloc[index]['avg']
    individual_avg_sum = dictionary.get(player1)+dictionary.get(player2)
    if(combined > individual_avg_sum):
        afg_beautiful2grams = afg_beautiful2grams.append({'player-1':player1, 'player-2':player2, 'combined_avg': combined, 'sum_of_individual':individual_avg_sum}, ignore_index=True)

# %%
afg_beautiful2grams.head()
# Out:
#        player-1            player-2  combined_avg  sum_of_individual
# 0  Taskin Ahmed       Nasir Hossain     12.090909              11.88
# 1  Taskin Ahmed        Anamul Haque     29.500000              17.58
# 2  Taskin Ahmed     Mushfiqur Rahim     41.458333              40.81
# 3  Taskin Ahmed  Mehidy Hasan Miraz     27.333333              11.55
# 4  Taskin Ahmed       Sabbir Rahman     24.192308              22.63

# %%
afg_beautiful2grams.shape
# Out:
# (154, 4)

# %%
afg_beautiful2grams.to_csv('bdesh2grams_won.csv')
